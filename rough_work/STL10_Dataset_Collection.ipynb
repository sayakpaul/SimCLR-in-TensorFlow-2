# %% [markdown]
# <a href="https://colab.research.google.com/github/sayakpaul/SimCLR-in-TensorFlow-2/blob/master/STL10_Dataset_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Dataset homepage: http://ai.stanford.edu/~acoates/stl10/
# - The Python script comes from: https://github.com/mttk/STL10/

# %%
# !wget https://raw.githubusercontent.com/mttk/STL10/master/stl10_input.py

# %%
# !python stl10_input.py

# %%
# !sudo apt-get install tree

# %%
# !mkdir stl10
# !cp -r train stl10/
# !cp -r test stl10/
# !cp -r unlabeled stl10/

# %%
# !tree --dirsfirst --filelimit 10 stl10
# Out:
# stl10
# ├── test
# │   ├── 1 [800 entries exceeds filelimit, not opening dir]
# │   ├── 10 [800 entries exceeds filelimit, not opening dir]
# │   ├── 2 [800 entries exceeds filelimit, not opening dir]
# │   ├── 3 [800 entries exceeds filelimit, not opening dir]
# │   ├── 4 [800 entries exceeds filelimit, not opening dir]
# │   ├── 5 [800 entries exceeds filelimit, not opening dir]
# │   ├── 6 [800 entries exceeds filelimit, not opening dir]
# │   ├── 7 [800 entries exceeds filelimit, not opening dir]
# │   ├── 8 [800 entries exceeds filelimit, not opening dir]
# │   └── 9 [800 entries exceeds filelimit, not opening dir]
# ├── train
# │   ├── 1 [500 entries exceeds filelimit, not opening dir]
# │   ├── 10 [500 entries exceeds filelimit, not opening dir]
# │   ├── 2 [500 entries exceeds filelimit, not opening dir]
# │   ├── 3 [500 entries exceeds filelimit, not opening dir]
# │   ├── 4 [500 entries exceeds filelimit, not opening dir]
# │   ├── 5 [500 entries exceeds filelimit, not opening dir]
# │   ├── 6 [500 entries exceeds filelimit, not opening dir]
# │   ├── 7 [500 entries exceeds filelimit, not opening dir]
# │   ├── 8 [500 entries exceeds filelimit, not opening dir]
# │   └── 9 [500 entries exceeds filelimit, not opening dir]
# └── unlabeled [100000 entries exceeds filelimit, not opening dir]
#
# 23 directories, 0 files

# %%
# Set up GCP
PROJECT_ID = "fast-ai-exploration"
# !gcloud config set project $PROJECT_ID
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
# Create a GCS bucket and copy the images
# !gsutil mb gs://stl10
# !gsutil -m cp -r train gs://stl10
# !gsutil -m cp -r test gs://stl10
# !gsutil -m cp -r unlabeled gs://stl10
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file://test/8/5128.png [Content-Type=image/png]...
# Copying file://test/8/697.png [Content-Type=image/png]...
# Copying file://test/8/5719.png [Content-Type=image/png]...
# Copying file://test/8/1122.png [Content-Type=image/png]...
# Copying file://test/8/4663.png [Content-Type=image/png]...
# Copying file://test/8/635.png [Content-Type=image/png]...
# Copying file://test/8/1452.png [Content-Type=image/png]...
# Copying file://test/8/4571.png [Content-Type=image/png]...
# Copying file://test/8/7764.png [Content-Type=image/png]...
# Copying file://test/8/2826.png [Content-Type=image/png]...
# Copying file://test/8/377.png [Content-Type=image/png]...
# Copying file://test/8/6549.png [Content-Type=image/png]...
# Copying file://test/8/3514.png [Content-Type=image/png]...
# Copying file://test/8/4628.png [Content-Type=image/png]...
# Copying file://test/8/105.png [Content-Type=image/png]...
# Copying file://test/8/620.png [Content-Type=image/png]...
# Copying file://test/8/7964.png [Content-Type=image/png]...
# Copying file://test/8/5813.png [Content-Type=image/png]...
# Copying file://test/8/5278.png [Content-Type=image/png]...
# Copying file://test/8/2037.png [Content-Type=image/png]...
# Copying file://test/8/6190.png [Content-Type=image/png]...
# Copying file://test/8/2455.png [Content-Type=image/png]...
# Copying file://test/8/4816.png [Content-Type=image/png]...
# Copying file://test/8/1417.png [Content-Type=image/png]...
# Copying file://test/8/3178.png [Content-Type=image/png]...
# Copying file://test/8/5657.png [Content-Type=image/png]...
# Copying file://test/8/4995.png [Content-Type=image/png]...
# Copying file://test/8/466.png [Content-Type=image/png]...
# Copying file://test/8/7730.png [Content-Type=image/png]...
# Copying file://test/8/7748.png [Content-Type=image/png]...
# Copying file://test/8/5977.png [Content-Type=image/png]...
# Copying file://test/8/37.png [Content-Type=image/png]...
# Copying file://test/8/1608.png [Content-Type=image/png]...
# Copying file://test/8/3665.png [Content-Type=image/png]...
# Copying file://test/8/1734.png [Content-Type=image/png]...
# Copying file://test/8/1364.png [Content-Type=image/png]...
# Copying file://test/8/3341.png [Content-Type=image/png]...
# Copying file://test/8/833.png [Content-Type=image/png]...
# Copying file://test/8/1329.png [Content-Type=image/png]...
# Copying file://test/8/7407.png [Content-Type=image/png]...
# Copying file://test/8/3153.png [Content-Type=image/png]...
# Copying file://test/8/7608.png [Content-Type=image/png]...
# Copying file://test/8/3952.png [Content-Type=image/png]...
# Copying file://test/8/3680.png [Content-Type=image/png]...
# Copying file://test/8/5499.png [Content-Type=image/png]...
# Copying file://test/8/5196.png [Content-Type=image/png]...
# Copying file://test/8/5576.png [Content-Type=image/png]...
# Copying file://test/8/3839.png [Content-Type=image/png]...
# Copying file://test/8/6217.png [Content-Type=image/png]...
# Copying file://test/8/7424.png [Content-Type=image/png]...
# Copying file://test/8/4236.png [Content-Type=image/png]...
# Copying file://test/8/5895.png [Content-Type=image/png]...
# Copying file://test/8/4901.png [Content-Type=image/png]...
# Copying file://test/8/5495.png [Content-Type=image/png]...
# Copying file://test/8/3682.png [Content-Type=image/png]...
# Copying file://test/8/4467.png [Content-Type=image/png]...
# Copying file://test/8/1342.png [Content-Type=image/png]...
# Copying file://test/8/2905.png [Content-Type=image/png]...
# Copying file://test/8/33.png [Content-Type=image/png]...
# Copying file://test/8/6961.png [Content-Type=image/png]...
# Copying file://test/8/4331.png [Content-Type=image/png]...
# Copying file://test/8/5232.png [Content-Type=image/png]...
# Copying file://test/8/3100.png [Content-Type=image/png]...
# Copying file://test/8/6727.png [Content-Type=image/png]...
# Copying file://test/8/3850.png [Content-Type=image/png]...
# Copying file://test/8/2219.png [Content-Type=image/png]...
# Copying file://test/8/5200.png [Content-Type=image/png]...
# Copying file://test/8/7134.png [Content-Type=image/png]...
# Copying file://test/8/5401.png [Content-Type=image/png]...
# Copying file://test/8/1557.png [Content-Type=image/png]...
# Copying file://test/8/5995.png [Content-Type=image/png]...
# Copying file://test/8/4080.png [Content-Type=image/png]...
# Copying file://test/8/5593.png [Content-Type=image/png]...
# Copying file://test/8/3592.png [Content-Type=image/png]...
# Copying file://test/8/6229.png [Content-Type=image/png]...
# Copying file://test/8/2020.png [Content-Type=image/png]...
# Copying file://test/8/3319.png [Content-Type=image/png]...
# Copying file://test/8/5527.png [Content-Type=image/png]...
# Copying file://test/8/4985.png [Content-Type=image/png]...
# Copying file://test/8/575.png [Content-Type=image/png]...
# Copying file://test/8/804.png [Content-Type=image/png]...
# Copying file://test/8/5086.png [Content-Type=image/png]...
# Copying file://test/8/4515.png [Content-Type=image/png]...
# Copying file://test/8/156.png [Content-Type=image/png]...
# Copying file://test/8/7391.png [Content-Type=image/png]...
# Copying file://test/8/2269.png [Content-Type=image/png]...
# Copying file://test/8/7168.png [Content-Type=image/png]...
# Copying file://test/8/4263.png [Content-Type=image/png]...
# Copying file://test/8/2000.png [Content-Type=image/png]...
# Copying file://test/8/7870.png [Content-Type=image/png]...
# Copying file://test/8/2001.png [Content-Type=image/png]...
# Copying file://test/8/1274.png [Content-Type=image/png]...
# Copying file://test/8/4139.png [Content-Type=image/png]...
# Copying file://test/8/6281.png [Content-Type=image/png]...
# Copying file://test/8/4790.png [Content-Type=image/png]...
# Copying file://test/8/6301.png [Content-Type=image/png]...
# Copying file://test/8/3029.png [Content-Type=image/png]...
# Copying file://test/8/4778.png [Content-Type=image/png]...
# Copying file://test/8/3380.png [Content-Type=image/png]...
# Copying file://test/8/2221.png [Content-Type=image/png]...
# Copying file://test/8/7619.png [Content-Type=image/png]...
# Copying file://test/8/6673.png [Content-Type=image/png]...
# Copying file://test/8/4565.png [Content-Type=image/png]...
# Copying file://test/8/1354.png [Content-Type=image/png]...
# Copying file://test/8/6527.png [Content-Type=image/png]...
# Copying file://test/8/5806.png [Content-Type=image/png]...
# Copying file://test/8/2437.png [Content-Type=image/png]...
# Copying file://test/8/3571.png [Content-Type=image/png]...
# Copying file://test/8/2649.png [Content-Type=image/png]...
# Copying file://test/8/1514.png [Content-Type=image/png]...
# Copying file://test/8/6905.png [Content-Type=image/png]...
# Copying file://test/8/6876.png [Content-Type=image/png]...
# Copying file://test/8/6456.png [Content-Type=image/png]...
# Copying file://test/8/1661.png [Content-Type=image/png]...
# Copying file://test/8/4859.png [Content-Type=image/png]...
# Copying file://test/8/3967.png [Content-Type=image/png]...
# Copying file://test/8/1771.png [Content-Type=image/png]...
# Copying file://test/8/6840.png [Content-Type=image/png]...
# Copying file://test/8/1372.png [Content-Type=image/png]...
# Copying file://test/8/1161.png [Content-Type=image/png]...
# Copying file://test/8/1566.png [Content-Type=image/png]...
# Copying file://test/8/2916.png [Content-Type=image/png]...
# Copying file://test/8/5126.png [Content-Type=image/png]...
# Copying file://test/8/7863.png [Content-Type=image/png]...
# Copying file://test/8/5413.png [Content-Type=image/png]...
# Copying file://test/8/6254.png [Content-Type=image/png]...
# Copying file://test/8/750.png [Content-Type=image/png]...
# Copying file://test/8/2787.png [Content-Type=image/png]...
# Copying file://test/8/1482.png [Content-Type=image/png]...
# Copying file://test/8/3756.png [Content-Type=image/png]...
# Copying file://test/8/3188.png [Content-Type=image/png]...
# Copying file://test/8/5672.png [Content-Type=image/png]...
# Copying file://test/8/1629.png [Content-Type=image/png]...
# Copying file://test/8/898.png [Content-Type=image/png]...
# Copying file://test/8/881.png [Content-Type=image/png]...
# Copying file://test/8/4210.png [Content-Type=image/png]...
# Copying file://test/8/5900.png [Content-Type=image/png]...
# Copying file://test/8/7044.png [Content-Type=image/png]...
# Copying file://test/8/4905.png [Content-Type=image/png]...
# Copying file://test/8/1519.png [Content-Type=image/png]...
# Copying file://test/8/5850.png [Content-Type=image/png]...
# Copying file://test/8/2901.png [Content-Type=image/png]...
# Copying file://test/8/2756.png [Content-Type=image/png]...
# Copying file://test/8/7660.png [Content-Type=image/png]...
# Copying file://test/8/5192.png [Content-Type=image/png]...
# Copying file://test/8/457.png [Content-Type=image/png]...
# Copying file://test/8/139.png [Content-Type=image/png]...
# Copying file://test/8/6809.png [Content-Type=image/png]...
# Copying file://test/8/7979.png [Content-Type=image/png]...
# Copying file://test/8/4475.png [Content-Type=image/png]...
# Copying file://test/8/4193.png [Content-Type=image/png]...
# Copying file://test/8/1243.png [Content-Type=image/png]...
# Copying file://test/8/2842.png [Content-Type=image/png]...
# Copying file://test/8/956.png [Content-Type=image/png]...
# Copying file://test/8/2883.png [Content-Type=image/png]...
# Copying file://test/8/7156.png [Content-Type=image/png]...
# Copying file://test/8/2808.png [Content-Type=image/png]...
# Copying file://test/8/3037.png [Content-Type=image/png]...
# Copying file://test/8/3335.png [Content-Type=image/png]...
# Copying file://test/8/63.png [Content-Type=image/png]...
# Copying file://test/8/6314.png [Content-Type=image/png]...
# Copying file://test/8/2858.png [Content-Type=image/png]...
# Copying file://test/8/7581.png [Content-Type=image/png]...
# Copying file://test/8/2182.png [Content-Type=image/png]...
# Copying file://test/8/902.png [Content-Type=image/png]...
# Copying file://test/8/4221.png [Content-Type=image/png]...
# Copying file://test/8/7866.png [Content-Type=image/png]...
# Copying file://test/8/6225.png [Content-Type=image/png]...
# Copying file://test/8/1607.png [Content-Type=image/png]...
# Copying file://test/8/4462.png [Content-Type=image/png]...
# Copying file://test/8/2773.png [Content-Type=image/png]...
# Copying file://test/8/3754.png [Content-Type=image/png]...
# Copying file://test/8/859.png [Content-Type=image/png]...
# Copying file://test/8/2651.png [Content-Type=image/png]...
# Copying file://test/8/4704.png [Content-Type=image/png]...
# Copying file://test/8/4403.png [Content-Type=image/png]...
# Copying file://test/8/6650.png [Content-Type=image/png]...
# Copying file://test/8/292.png [Content-Type=image/png]...
# Copying file://test/8/6586.png [Content-Type=image/png]...
# Copying file://test/8/325.png [Content-Type=image/png]...
# Copying file://test/8/3021.png [Content-Type=image/png]...
# Copying file://test/8/7930.png [Content-Type=image/png]...
# Copying file://test/8/2259.png [Content-Type=image/png]...
# Copying file://test/8/7023.png [Content-Type=image/png]...
# Copying file://test/8/6141.png [Content-Type=image/png]...
# Copying file://test/8/2885.png [Content-Type=image/png]...
# Copying file://test/8/576.png [Content-Type=image/png]...
# Copying file://test/8/5773.png [Content-Type=image/png]...
# Copying file://test/8/6031.png [Content-Type=image/png]...
# Copying file://test/8/1220.png [Content-Type=image/png]...
# Copying file://test/8/3673.png [Content-Type=image/png]...
# Copying file://test/8/6617.png [Content-Type=image/png]...
# Copying file://test/8/2262.png [Content-Type=image/png]...
# Copying file://test/8/5477.png [Content-Type=image/png]...
# Copying file://test/8/2161.png [Content-Type=image/png]...
# Copying file://test/8/1956.png [Content-Type=image/png]...
# Copying file://test/8/3192.png [Content-Type=image/png]...
# Copying file://test/8/152.png [Content-Type=image/png]...
# Copying file://test/8/7587.png [Content-Type=image/png]...
# Copying file://test/8/323.png [Content-Type=image/png]...
# Copying file://test/8/3367.png [Content-Type=image/png]...
# Copying file://test/8/1071.png [Content-Type=image/png]...
# Copying file://test/8/779.png [Content-Type=image/png]...
# Copying file://test/8/3564.png [Content-Type=image/png]...
# Copying file://test/8/6785.png [Content-Type=image/png]...
# Copying file://test/8/1020.png [Content-Type=image/png]...
# Copying file://test/8/4133.png [Content-Type=image/png]...
# Copying file://test/8/6392.png [Content-Type=image/png]...
# Copying file://test/8/5105.png [Content-Type=image/png]...
# Copying file://test/8/7024.png [Content-Type=image/png]...
# Copying file://test/8/696.png [Content-Type=image/png]...
# Copying file://test/8/3784.png [Content-Type=image/png]...
# Copying file://test/8/2997.png [Content-Type=image/png]...
# Copying file://test/8/5710.png [Content-Type=image/png]...
# Copying file://test/8/5993.png [Content-Type=image/png]...
# Copying file://test/8/6598.png [Content-Type=image/png]...
# Copying file://test/8/5679.png [Content-Type=image/png]...
# Copying file://test/8/7700.png [Content-Type=image/png]...
# Copying file://test/8/186.png [Content-Type=image/png]...
# Copying file://test/8/3906.png [Content-Type=image/png]...
# Copying file://test/8/4645.png [Content-Type=image/png]...
# Copying file://test/8/6140.png [Content-Type=image/png]...
# Copying file://test/8/7856.png [Content-Type=image/png]...
# Copying file://test/8/4371.png [Content-Type=image/png]...
# Copying file://test/8/4441.png [Content-Type=image/png]...
# Copying file://test/8/3814.png [Content-Type=image/png]...
# Copying file://test/8/2207.png [Content-Type=image/png]...
# Copying file://test/8/4843.png [Content-Type=image/png]...
# Copying file://test/8/3705.png [Content-Type=image/png]...
# Copying file://test/8/5984.png [Content-Type=image/png]...
# Copying file://test/8/2152.png [Content-Type=image/png]...
# Copying file://test/8/6580.png [Content-Type=image/png]...
# Copying file://test/8/4789.png [Content-Type=image/png]...
# Copying file://test/8/5770.png [Content-Type=image/png]...
# Copying file://test/8/1042.png [Content-Type=image/png]...
# Copying file://test/8/3659.png [Content-Type=image/png]...
# Copying file://test/8/4984.png [Content-Type=image/png]...
# Copying file://test/8/353.png [Content-Type=image/png]...
# Copying file://test/8/2596.png [Content-Type=image/png]...
# Copying file://test/8/6359.png [Content-Type=image/png]...
# Copying file://test/8/3044.png [Content-Type=image/png]...
# Copying file://test/8/5269.png [Content-Type=image/png]...
# Copying file://test/8/604.png [Content-Type=image/png]...
# Copying file://test/8/4138.png [Content-Type=image/png]...
# Copying file://test/9/3943.png [Content-Type=image/png]...
# Copying file://test/9/6998.png [Content-Type=image/png]...
# Copying file://test/9/6353.png [Content-Type=image/png]...
# Copying file://test/9/5845.png [Content-Type=image/png]...
# Copying file://test/9/7481.png [Content-Type=image/png]...
# Copying file://test/9/4196.png [Content-Type=image/png]...
# Copying file://test/9/5059.png [Content-Type=image/png]...
# Copying file://test/9/904.png [Content-Type=image/png]...
# Copying file://test/9/2093.png [Content-Type=image/png]...
# Copying file://test/9/4775.png [Content-Type=image/png]...
# Copying file://test/9/4119.png [Content-Type=image/png]...
# Copying file://test/9/7281.png [Content-Type=image/png]...
# Copying file://test/9/5555.png [Content-Type=image/png]...
# Copying file://test/9/4123.png [Content-Type=image/png]...
# Copying file://test/9/1346.png [Content-Type=image/png]...
# Copying file://test/9/4603.png [Content-Type=image/png]...
# Copying file://test/9/2330.png [Content-Type=image/png]...
# Copying file://test/9/2742.png [Content-Type=image/png]...
# Copying file://test/9/2792.png [Content-Type=image/png]...
# Copying file://test/9/5133.png [Content-Type=image/png]...
# Copying file://test/9/4994.png [Content-Type=image/png]...
# Copying file://test/9/2830.png [Content-Type=image/png]...
# Copying file://test/9/6253.png [Content-Type=image/png]...
# Copying file://test/9/4728.png [Content-Type=image/png]...
# Copying file://test/9/5516.png [Content-Type=image/png]...
# Copying file://test/9/2340.png [Content-Type=image/png]...
# Copying file://test/9/212.png [Content-Type=image/png]...
# Copying file://test/9/7893.png [Content-Type=image/png]...
# Copying file://test/9/6469.png [Content-Type=image/png]...
# Copying file://test/9/122.png [Content-Type=image/png]...
# Copying file://test/9/2972.png [Content-Type=image/png]...
# Copying file://test/9/6478.png [Content-Type=image/png]...
# Copying file://test/9/4524.png [Content-Type=image/png]...
# Copying file://test/9/4664.png [Content-Type=image/png]...
# Copying file://test/9/5727.png [Content-Type=image/png]...
# Copying file://test/9/5106.png [Content-Type=image/png]...
# Copying file://test/9/2553.png [Content-Type=image/png]...
# Copying file://test/9/2191.png [Content-Type=image/png]...
# Copying file://test/9/413.png [Content-Type=image/png]...
# Copying file://test/9/1119.png [Content-Type=image/png]...
# Copying file://test/9/3603.png [Content-Type=image/png]...
# Copying file://test/9/3637.png [Content-Type=image/png]...
# Copying file://test/9/5952.png [Content-Type=image/png]...
# Copying file://test/9/273.png [Content-Type=image/png]...
# Copying file://test/9/4072.png [Content-Type=image/png]...
# Copying file://test/9/6144.png [Content-Type=image/png]...
# Copying file://test/9/7997.png [Content-Type=image/png]...
# Copying file://test/9/5231.png [Content-Type=image/png]...
# Copying file://test/9/1197.png [Content-Type=image/png]...
# Copying file://test/9/6764.png [Content-Type=image/png]...
# Copying file://test/9/4979.png [Content-Type=image/png]...
# Copying file://test/9/232.png [Content-Type=image/png]...
# Copying file://test/9/609.png [Content-Type=image/png]...
# Copying file://test/9/2429.png [Content-Type=image/png]...
# Copying file://test/9/3213.png [Content-Type=image/png]...
# Copying file://test/9/1496.png [Content-Type=image/png]...
# Copying file://test/9/4769.png [Content-Type=image/png]...
# Copying file://test/9/2204.png [Content-Type=image/png]...
# Copying file://test/9/4876.png [Content-Type=image/png]...
# Copying file://test/9/7319.png [Content-Type=image/png]...
# Copying file://test/9/4256.png [Content-Type=image/png]...
# Copying file://test/9/4311.png [Content-Type=image/png]...
# Copying file://test/9/2749.png [Content-Type=image/png]...
# Copying file://test/9/6964.png [Content-Type=image/png]...
# Copying file://test/9/4458.png [Content-Type=image/png]...
# Copying file://test/9/7050.png [Content-Type=image/png]...
# Copying file://test/9/6277.png [Content-Type=image/png]...
# Copying file://test/9/270.png [Content-Type=image/png]...
# Copying file://test/9/5387.png [Content-Type=image/png]...
# Copying file://test/9/388.png [Content-Type=image/png]...
# Copying file://test/9/939.png [Content-Type=image/png]...
# Copying file://test/9/3391.png [Content-Type=image/png]...
# Copying file://test/9/1729.png [Content-Type=image/png]...
# Copying file://test/9/7132.png [Content-Type=image/png]...
# Copying file://test/9/5073.png [Content-Type=image/png]...
# Copying file://test/9/962.png [Content-Type=image/png]...
# Copying file://test/9/678.png [Content-Type=image/png]...
# Copying file://test/9/3709.png [Content-Type=image/png]...
# Copying file://test/9/7920.png [Content-Type=image/png]...
# Copying file://test/9/2486.png [Content-Type=image/png]...
# Copying file://test/9/2418.png [Content-Type=image/png]...
# Copying file://test/9/3445.png [Content-Type=image/png]...
# Copying file://test/9/6447.png [Content-Type=image/png]...
# Copying file://test/9/2660.png [Content-Type=image/png]...
# Copying file://test/9/3197.png [Content-Type=image/png]...
# Copying file://test/9/4237.png [Content-Type=image/png]...
# Copying file://test/9/7753.png [Content-Type=image/png]...
# Copying file://test/9/362.png [Content-Type=image/png]...
# Copying file://test/9/3976.png [Content-Type=image/png]...
# Copying file://test/9/1590.png [Content-Type=image/png]...
# Copying file://test/9/5743.png [Content-Type=image/png]...
# Copying file://test/9/7114.png [Content-Type=image/png]...
# Copying file://test/9/912.png [Content-Type=image/png]...
# Copying file://test/9/2684.png [Content-Type=image/png]...
# Copying file://test/9/6858.png [Content-Type=image/png]...
# Copying file://test/9/739.png [Content-Type=image/png]...
# Copying file://test/9/998.png [Content-Type=image/png]...
# Copying file://test/9/1666.png [Content-Type=image/png]...
# Copying file://test/9/4203.png [Content-Type=image/png]...
# Copying file://test/9/7681.png [Content-Type=image/png]...
# Copying file://test/9/2211.png [Content-Type=image/png]...
# Copying file://test/9/1093.png [Content-Type=image/png]...
# Copying file://test/9/3119.png [Content-Type=image/png]...
# Copying file://test/9/7929.png [Content-Type=image/png]...
# Copying file://test/9/4756.png [Content-Type=image/png]...
# Copying file://test/9/460.png [Content-Type=image/png]...
# Copying file://test/9/55.png [Content-Type=image/png]...
# Copying file://test/9/7908.png [Content-Type=image/png]...
# Copying file://test/9/6870.png [Content-Type=image/png]...
# Copying file://test/9/3703.png [Content-Type=image/png]...
# Copying file://test/9/7716.png [Content-Type=image/png]...
# Copying file://test/9/5190.png [Content-Type=image/png]...
# Copying file://test/9/6148.png [Content-Type=image/png]...
# Copying file://test/9/2795.png [Content-Type=image/png]...
# Copying file://test/9/3650.png [Content-Type=image/png]...
# Copying file://test/9/5807.png [Content-Type=image/png]...
# Copying file://test/9/2059.png [Content-Type=image/png]...
# Copying file://test/9/4326.png [Content-Type=image/png]...
# Copying file://test/9/4939.png [Content-Type=image/png]...
# Copying file://test/9/6765.png [Content-Type=image/png]...
# Copying file://test/9/2860.png [Content-Type=image/png]...
# Copying file://test/9/4627.png [Content-Type=image/png]...
# Copying file://test/9/2447.png [Content-Type=image/png]...
# Copying file://test/9/1865.png [Content-Type=image/png]...
# Copying file://test/9/5134.png [Content-Type=image/png]...
# Copying file://test/9/2055.png [Content-Type=image/png]...
# Copying file://test/9/1503.png [Content-Type=image/png]...
# Copying file://test/9/4621.png [Content-Type=image/png]...
# Copying file://test/9/4666.png [Content-Type=image/png]...
# Copying file://test/9/1783.png [Content-Type=image/png]...
# Copying file://test/9/4552.png [Content-Type=image/png]...
# Copying file://test/9/2922.png [Content-Type=image/png]...
# Copying file://test/9/5481.png [Content-Type=image/png]...
# Copying file://test/9/1747.png [Content-Type=image/png]...
# Copying file://test/9/7436.png [Content-Type=image/png]...
# Copying file://test/9/6165.png [Content-Type=image/png]...
# Copying file://test/9/3631.png [Content-Type=image/png]...
# Copying file://test/9/5735.png [Content-Type=image/png]...
# Copying file://test/9/6095.png [Content-Type=image/png]...
# Copying file://test/9/4797.png [Content-Type=image/png]...
# Copying file://test/9/4578.png [Content-Type=image/png]...
# Copying file://test/9/6290.png [Content-Type=image/png]...
# Copying file://test/9/1267.png [Content-Type=image/png]...
# Copying file://test/9/5950.png [Content-Type=image/png]...
# Copying file://test/9/6302.png [Content-Type=image/png]...
# Copying file://test/9/7477.png [Content-Type=image/png]...
# Copying file://test/9/1255.png [Content-Type=image/png]...
# Copying file://test/9/4382.png [Content-Type=image/png]...
# Copying file://test/9/5548.png [Content-Type=image/png]...
# Copying file://test/9/2109.png [Content-Type=image/png]...
# Copying file://test/9/6996.png [Content-Type=image/png]...
# Copying file://test/9/1922.png [Content-Type=image/png]...
# Copying file://test/9/2155.png [Content-Type=image/png]...
# Copying file://test/9/4927.png [Content-Type=image/png]...
# Copying file://test/9/2002.png [Content-Type=image/png]...
# Copying file://test/9/5932.png [Content-Type=image/png]...
# Copying file://test/9/430.png [Content-Type=image/png]...
# Copying file://test/9/6223.png [Content-Type=image/png]...
# Copying file://test/9/6962.png [Content-Type=image/png]...
# Copying file://test/9/737.png [Content-Type=image/png]...
# Copying file://test/9/7609.png [Content-Type=image/png]...
# Copying file://test/9/5758.png [Content-Type=image/png]...
# Copying file://test/9/2489.png [Content-Type=image/png]...
# Copying file://test/9/3097.png [Content-Type=image/png]...
# Copying file://test/9/2929.png [Content-Type=image/png]...
# Copying file://test/9/789.png [Content-Type=image/png]...
# Copying file://test/9/4069.png [Content-Type=image/png]...
# Copying file://test/9/3280.png [Content-Type=image/png]...
# Copying file://test/9/7532.png [Content-Type=image/png]...
# Copying file://test/9/4655.png [Content-Type=image/png]...
# Copying file://test/9/7875.png [Content-Type=image/png]...
# Copying file://test/9/6717.png [Content-Type=image/png]...
# Copying file://test/9/4511.png [Content-Type=image/png]...
# Copying file://test/9/334.png [Content-Type=image/png]...
# Copying file://test/9/3146.png [Content-Type=image/png]...
# Copying file://test/9/6675.png [Content-Type=image/png]...
# Copying file://test/9/4067.png [Content-Type=image/png]...
# Copying file://test/9/3290.png [Content-Type=image/png]...
# Copying file://test/9/1129.png [Content-Type=image/png]...
# Copying file://test/9/3878.png [Content-Type=image/png]...
# Copying file://test/9/7138.png [Content-Type=image/png]...
# Copying file://test/9/3403.png [Content-Type=image/png]...
# Copying file://test/9/4076.png [Content-Type=image/png]...
# Copying file://test/9/6841.png [Content-Type=image/png]...
# Copying file://test/9/366.png [Content-Type=image/png]...
# Copying file://test/9/3829.png [Content-Type=image/png]...
# Copying file://test/9/1999.png [Content-Type=image/png]...
# Copying file://test/9/2978.png [Content-Type=image/png]...
# Copying file://test/9/4902.png [Content-Type=image/png]...
# Copying file://test/9/3954.png [Content-Type=image/png]...
# Copying file://test/9/2500.png [Content-Type=image/png]...
# Copying file://test/9/906.png [Content-Type=image/png]...
# Copying file://test/9/2188.png [Content-Type=image/png]...
# Copying file://test/9/3311.png [Content-Type=image/png]...
# Copying file://test/9/7323.png [Content-Type=image/png]...
# Copying file://test/9/1826.png [Content-Type=image/png]...
# Copying file://test/9/1777.png [Content-Type=image/png]...
# Copying file://test/9/3477.png [Content-Type=image/png]...
# Copying file://test/9/6365.png [Content-Type=image/png]...
# Copying file://test/9/126.png [Content-Type=image/png]...
# Copying file://test/9/151.png [Content-Type=image/png]...
# Copying file://test/9/5838.png [Content-Type=image/png]...
# Copying file://test/9/242.png [Content-Type=image/png]...
# Copying file://test/9/1164.png [Content-Type=image/png]...
# Copying file://test/9/3608.png [Content-Type=image/png]...
# Copying file://test/9/6607.png [Content-Type=image/png]...
# Copying file://test/9/6570.png [Content-Type=image/png]...
# Copying file://test/9/441.png [Content-Type=image/png]...
# Copying file://test/9/4202.png [Content-Type=image/png]...
# Copying file://test/9/3734.png [Content-Type=image/png]...
# Copying file://test/9/5573.png [Content-Type=image/png]...
# Copying file://test/9/553.png [Content-Type=image/png]...
# Copying file://test/9/4285.png [Content-Type=image/png]...
# Copying file://test/9/6852.png [Content-Type=image/png]...
# Copying file://test/9/1465.png [Content-Type=image/png]...
# Copying file://test/9/1628.png [Content-Type=image/png]...
# Copying file://test/9/5191.png [Content-Type=image/png]...
# Copying file://test/9/5000.png [Content-Type=image/png]...
# Copying file://test/9/4649.png [Content-Type=image/png]...
# Copying file://test/9/7353.png [Content-Type=image/png]...
# Copying file://test/9/7573.png [Content-Type=image/png]...
# Copying file://test/9/4592.png [Content-Type=image/png]...
# Copying file://test/9/6286.png [Content-Type=image/png]...
# Copying file://test/9/6862.png [Content-Type=image/png]...
# Copying file://test/9/6625.png [Content-Type=image/png]...
# Copying file://test/9/6060.png [Content-Type=image/png]...
# Copying file://test/9/6388.png [Content-Type=image/png]...
# Copying file://test/9/1952.png [Content-Type=image/png]...
# Copying file://test/9/6001.png [Content-Type=image/png]...
# Copying file://test/9/7180.png [Content-Type=image/png]...
# Copying file://test/9/1055.png [Content-Type=image/png]...
# Copying file://test/9/2253.png [Content-Type=image/png]...
# Copying file://test/9/2117.png [Content-Type=image/png]...
# Copying file://test/9/5795.png [Content-Type=image/png]...
# Copying file://test/9/1855.png [Content-Type=image/png]...
# Copying file://test/9/2047.png [Content-Type=image/png]...
# Copying file://test/9/4434.png [Content-Type=image/png]...
# Copying file://test/9/4622.png [Content-Type=image/png]...
# Copying file://test/9/7092.png [Content-Type=image/png]...
# Copying file://test/9/4017.png [Content-Type=image/png]...
# Copying file://test/9/2983.png [Content-Type=image/png]...
# Copying file://test/9/2349.png [Content-Type=image/png]...
# Copying file://test/9/290.png [Content-Type=image/png]...
# Copying file://test/9/673.png [Content-Type=image/png]...
# Copying file://test/9/3736.png [Content-Type=image/png]...
# Copying file://test/9/2394.png [Content-Type=image/png]...
# Copying file://test/9/4823.png [Content-Type=image/png]...
# Copying file://test/9/100.png [Content-Type=image/png]...
# Copying file://test/9/4058.png [Content-Type=image/png]...
# Copying file://test/9/3111.png [Content-Type=image/png]...
# Copying file://test/9/86.png [Content-Type=image/png]...
# Copying file://test/9/6167.png [Content-Type=image/png]...
# Copying file://test/9/777.png [Content-Type=image/png]...
# Copying file://test/9/3099.png [Content-Type=image/png]...
# Copying file://test/9/7393.png [Content-Type=image/png]...
# Copying file://test/9/2580.png [Content-Type=image/png]...
# Copying file://test/9/494.png [Content-Type=image/png]...
# Copying file://test/9/7918.png [Content-Type=image/png]...
# Copying file://test/9/824.png [Content-Type=image/png]...
# Copying file://test/9/5816.png [Content-Type=image/png]...
# Copying file://test/9/193.png [Content-Type=image/png]...
# Copying file://test/9/4307.png [Content-Type=image/png]...
# Copying file://test/9/6091.png [Content-Type=image/png]...
# Copying file://test/9/1105.png [Content-Type=image/png]...
# Copying file://test/9/903.png [Content-Type=image/png]...
# Copying file://test/9/5531.png [Content-Type=image/png]...
# Copying file://test/9/6162.png [Content-Type=image/png]...
# Copying file://test/9/2498.png [Content-Type=image/png]...
# Copying file://test/9/7859.png [Content-Type=image/png]...
# Copying file://test/9/4128.png [Content-Type=image/png]...
# Copying file://test/9/2355.png [Content-Type=image/png]...
# Copying file://test/9/7999.png [Content-Type=image/png]...
# Copying file://test/9/2327.png [Content-Type=image/png]...
# Copying file://test/9/4100.png [Content-Type=image/png]...
# Copying file://test/9/6744.png [Content-Type=image/png]...
# Copying file://test/9/5340.png [Content-Type=image/png]...
# Copying file://test/9/165.png [Content-Type=image/png]...
# Copying file://test/9/7462.png [Content-Type=image/png]...
# Copying file://test/9/3250.png [Content-Type=image/png]...
# Copying file://test/9/3478.png [Content-Type=image/png]...
# Copying file://test/9/5862.png [Content-Type=image/png]...
# Copying file://test/9/2656.png [Content-Type=image/png]...
# Copying file://test/9/6518.png [Content-Type=image/png]...
# Copying file://test/9/4367.png [Content-Type=image/png]...
# Copying file://test/9/4425.png [Content-Type=image/png]...
# Copying file://test/9/2798.png [Content-Type=image/png]...
# Copying file://test/9/6752.png [Content-Type=image/png]...
# Copying file://test/9/1616.png [Content-Type=image/png]...
# Copying file://test/9/6946.png [Content-Type=image/png]...
# Copying file://test/9/5063.png [Content-Type=image/png]...
# Copying file://test/9/7868.png [Content-Type=image/png]...
# Copying file://test/9/4380.png [Content-Type=image/png]...
# Copying file://test/9/4242.png [Content-Type=image/png]...
# Copying file://test/9/6457.png [Content-Type=image/png]...
# Copying file://test/9/2738.png [Content-Type=image/png]...
# Copying file://test/9/5474.png [Content-Type=image/png]...
# Copying file://test/9/414.png [Content-Type=image/png]...
# Copying file://test/9/2844.png [Content-Type=image/png]...
# Copying file://test/9/6615.png [Content-Type=image/png]...
# Copying file://test/9/6234.png [Content-Type=image/png]...
# Copying file://test/9/3922.png [Content-Type=image/png]...
# Copying file://test/9/801.png [Content-Type=image/png]...
# Copying file://test/9/492.png [Content-Type=image/png]...
# Copying file://test/9/6940.png [Content-Type=image/png]...
# Copying file://test/9/1094.png [Content-Type=image/png]...
# Copying file://test/9/5437.png [Content-Type=image/png]...
# Copying file://test/9/2173.png [Content-Type=image/png]...
# Copying file://test/9/6443.png [Content-Type=image/png]...
# Copying file://test/9/6134.png [Content-Type=image/png]...
# Copying file://test/9/1219.png [Content-Type=image/png]...
# Copying file://test/9/5390.png [Content-Type=image/png]...
# Copying file://test/9/7965.png [Content-Type=image/png]...
# Copying file://test/9/2335.png [Content-Type=image/png]...
# Copying file://test/9/2074.png [Content-Type=image/png]...
# Copying file://test/9/3986.png [Content-Type=image/png]...
# Copying file://test/9/2039.png [Content-Type=image/png]...
# Copying file://test/9/3816.png [Content-Type=image/png]...
# Copying file://test/9/112.png [Content-Type=image/png]...
# Copying file://test/9/1294.png [Content-Type=image/png]...
# Copying file://test/9/6047.png [Content-Type=image/png]...
# Copying file://test/9/3583.png [Content-Type=image/png]...
# Copying file://test/9/7508.png [Content-Type=image/png]...
# Copying file://test/9/3691.png [Content-Type=image/png]...
# Copying file://test/9/5487.png [Content-Type=image/png]...
# Copying file://test/9/6173.png [Content-Type=image/png]...
# Copying file://test/9/1054.png [Content-Type=image/png]...
# Copying file://test/9/6183.png [Content-Type=image/png]...
# Copying file://test/9/2026.png [Content-Type=image/png]...
# Copying file://test/9/698.png [Content-Type=image/png]...
# Copying file://test/9/5441.png [Content-Type=image/png]...
# Copying file://test/9/3684.png [Content-Type=image/png]...
# Copying file://test/9/2192.png [Content-Type=image/png]...
# Copying file://test/9/7212.png [Content-Type=image/png]...
# Copying file://test/9/6563.png [Content-Type=image/png]...
# Copying file://test/9/5940.png [Content-Type=image/png]...
# Copying file://test/9/3525.png [Content-Type=image/png]...
# Copying file://test/9/3725.png [Content-Type=image/png]...
# Copying file://test/9/7007.png [Content-Type=image/png]...
# Copying file://test/9/742.png [Content-Type=image/png]...
# Copying file://test/9/2287.png [Content-Type=image/png]...
# Copying file://test/9/6377.png [Content-Type=image/png]...
# Copying file://test/9/182.png [Content-Type=image/png]...
# Copying file://test/9/7252.png [Content-Type=image/png]...
# Copying file://test/9/6698.png [Content-Type=image/png]...
# Copying file://test/9/7821.png [Content-Type=image/png]...
# Copying file://test/9/1363.png [Content-Type=image/png]...
# Copying file://test/9/3130.png [Content-Type=image/png]...
# Copying file://test/9/2941.png [Content-Type=image/png]...
# Copying file://test/9/7998.png [Content-Type=image/png]...
# Copying file://test/9/7240.png [Content-Type=image/png]...
# Copying file://test/9/3283.png [Content-Type=image/png]...
# Copying file://test/9/702.png [Content-Type=image/png]...
# Copying file://test/9/6110.png [Content-Type=image/png]...
# Copying file://test/9/1834.png [Content-Type=image/png]...
# Copying file://test/9/6888.png [Content-Type=image/png]...
# Copying file://test/9/5146.png [Content-Type=image/png]...
# Copying file://test/9/3030.png [Content-Type=image/png]...
# Copying file://test/9/5859.png [Content-Type=image/png]...
# Copying file://test/9/4164.png [Content-Type=image/png]...
# Copying file://test/9/6303.png [Content-Type=image/png]...
# Copying file://test/9/716.png [Content-Type=image/png]...
# Copying file://test/9/667.png [Content-Type=image/png]...
# Copying file://test/9/4319.png [Content-Type=image/png]...
# Copying file://test/9/2487.png [Content-Type=image/png]...
# Copying file://test/9/5504.png [Content-Type=image/png]...
# Copying file://test/9/591.png [Content-Type=image/png]...
# Copying file://test/9/5766.png [Content-Type=image/png]...
# Copying file://test/9/539.png [Content-Type=image/png]...
# Copying file://test/9/2662.png [Content-Type=image/png]...
# Copying file://test/9/1816.png [Content-Type=image/png]...
# Copying file://test/9/6532.png [Content-Type=image/png]...
# Copying file://test/9/6055.png [Content-Type=image/png]...
# Copying file://test/9/1079.png [Content-Type=image/png]...
# Copying file://test/9/6904.png [Content-Type=image/png]...
# Copying file://test/9/2991.png [Content-Type=image/png]...
# Copying file://test/9/1133.png [Content-Type=image/png]...
# Copying file://test/9/6027.png [Content-Type=image/png]...
# Copying file://test/9/7362.png [Content-Type=image/png]...
# Copying file://test/9/4324.png [Content-Type=image/png]...
# Copying file://test/9/5518.png [Content-Type=image/png]...
# Copying file://test/9/1002.png [Content-Type=image/png]...
# Copying file://test/9/7810.png [Content-Type=image/png]...
# Copying file://test/9/5097.png [Content-Type=image/png]...
# Copying file://test/9/610.png [Content-Type=image/png]...
# Copying file://test/9/1752.png [Content-Type=image/png]...
# Copying file://test/9/3065.png [Content-Type=image/png]...
# Copying file://test/9/4230.png [Content-Type=image/png]...
# Copying file://test/9/5398.png [Content-Type=image/png]...
# Copying file://test/9/1117.png [Content-Type=image/png]...
# Copying file://test/9/2657.png [Content-Type=image/png]...
# Copying file://test/9/5497.png [Content-Type=image/png]...
# Copying file://test/9/6633.png [Content-Type=image/png]...
# Copying file://test/9/6487.png [Content-Type=image/png]...
# Copying file://test/9/3818.png [Content-Type=image/png]...
# Copying file://test/9/4391.png [Content-Type=image/png]...
# Copying file://test/9/6101.png [Content-Type=image/png]...
# Copying file://test/9/452.png [Content-Type=image/png]...
# Copying file://test/9/374.png [Content-Type=image/png]...
# Copying file://test/9/2926.png [Content-Type=image/png]...
# Copying file://test/9/6835.png [Content-Type=image/png]...
# Copying file://test/9/4197.png [Content-Type=image/png]...
# Copying file://test/9/3644.png [Content-Type=image/png]...
# Copying file://test/9/1640.png [Content-Type=image/png]...
# Copying file://test/9/2856.png [Content-Type=image/png]...
# Copying file://test/9/2731.png [Content-Type=image/png]...
# Copying file://test/9/1785.png [Content-Type=image/png]...
# Copying file://test/9/3412.png [Content-Type=image/png]...
# Copying file://test/9/2185.png [Content-Type=image/png]...
# Copying file://test/9/184.png [Content-Type=image/png]...
# Copying file://test/9/2371.png [Content-Type=image/png]...
# Copying file://test/9/2526.png [Content-Type=image/png]...
# Copying file://test/9/6434.png [Content-Type=image/png]...
# Copying file://test/9/2562.png [Content-Type=image/png]...
# Copying file://test/9/878.png [Content-Type=image/png]...
# Copying file://test/9/5482.png [Content-Type=image/png]...
# Copying file://test/9/159.png [Content-Type=image/png]...
# Copying file://test/9/5171.png [Content-Type=image/png]...
# Copying file://test/9/7976.png [Content-Type=image/png]...
# Copying file://test/9/1873.png [Content-Type=image/png]...
# Copying file://test/9/2601.png [Content-Type=image/png]...
# Copying file://test/9/3479.png [Content-Type=image/png]...
# Copying file://test/9/6697.png [Content-Type=image/png]...
# Copying file://test/9/688.png [Content-Type=image/png]...
# Copying file://test/9/7454.png [Content-Type=image/png]...
# Copying file://test/9/6712.png [Content-Type=image/png]...
# Copying file://test/9/556.png [Content-Type=image/png]...
# Copying file://test/9/7519.png [Content-Type=image/png]...
# Copying file://test/9/5549.png [Content-Type=image/png]...
# Copying file://test/9/7720.png [Content-Type=image/png]...
# Copying file://test/9/7394.png [Content-Type=image/png]...
# Copying file://test/9/1683.png [Content-Type=image/png]...
# Copying file://test/9/7095.png [Content-Type=image/png]...
# Copying file://test/9/7325.png [Content-Type=image/png]...
# Copying file://test/9/5969.png [Content-Type=image/png]...
# Copying file://test/9/2745.png [Content-Type=image/png]...
# Copying file://test/9/1137.png [Content-Type=image/png]...
# Copying file://test/9/4235.png [Content-Type=image/png]...
# Copying file://test/9/5302.png [Content-Type=image/png]...
# Copying file://test/9/5320.png [Content-Type=image/png]...
# Copying file://test/9/1037.png [Content-Type=image/png]...
# Copying file://test/9/6166.png [Content-Type=image/png]...
# Copying file://test/9/6413.png [Content-Type=image/png]...
# Copying file://test/9/338.png [Content-Type=image/png]...
# Copying file://test/9/2115.png [Content-Type=image/png]...
# Copying file://test/9/4170.png [Content-Type=image/png]...
# Copying file://test/9/6914.png [Content-Type=image/png]...
# Copying file://test/9/1415.png [Content-Type=image/png]...
# Copying file://test/9/1735.png [Content-Type=image/png]...
# Copying file://test/9/5618.png [Content-Type=image/png]...
# Copying file://test/9/6643.png [Content-Type=image/png]...
# Copying file://test/9/7818.png [Content-Type=image/png]...
# Copying file://test/9/2174.png [Content-Type=image/png]...
# Copying file://test/9/4240.png [Content-Type=image/png]...
# Copying file://test/9/3905.png [Content-Type=image/png]...
# Copying file://test/9/2233.png [Content-Type=image/png]...
# Copying file://test/9/7417.png [Content-Type=image/png]...
# Copying file://test/9/4030.png [Content-Type=image/png]...
# Copying file://test/9/6156.png [Content-Type=image/png]...
# Copying file://test/9/6832.png [Content-Type=image/png]...
# Copying file://test/9/348.png [Content-Type=image/png]...
# Copying file://test/9/1375.png [Content-Type=image/png]...
# Copying file://test/9/2184.png [Content-Type=image/png]...
# Copying file://test/9/6012.png [Content-Type=image/png]...
# Copying file://test/9/7080.png [Content-Type=image/png]...
# Copying file://test/9/6707.png [Content-Type=image/png]...
# Copying file://test/9/958.png [Content-Type=image/png]...
# Copying file://test/9/602.png [Content-Type=image/png]...
# Copying file://test/9/6146.png [Content-Type=image/png]...
# Copying file://test/9/886.png [Content-Type=image/png]...
# Copying file://test/9/6689.png [Content-Type=image/png]...
# Copying file://test/9/1366.png [Content-Type=image/png]...
# Copying file://test/9/2621.png [Content-Type=image/png]...
# Copying file://test/9/5321.png [Content-Type=image/png]...
# Copying file://test/9/5053.png [Content-Type=image/png]...
# Copying file://test/9/229.png [Content-Type=image/png]...
# Copying file://test/9/6541.png [Content-Type=image/png]...
# Copying file://test/9/7205.png [Content-Type=image/png]...
# Copying file://test/9/1709.png [Content-Type=image/png]...
# Copying file://test/9/1494.png [Content-Type=image/png]...
# Copying file://test/9/4763.png [Content-Type=image/png]...
# Copying file://test/9/6147.png [Content-Type=image/png]...
# Copying file://test/9/911.png [Content-Type=image/png]...
# Copying file://test/9/955.png [Content-Type=image/png]...
# Copying file://test/9/5676.png [Content-Type=image/png]...
# Copying file://test/9/240.png [Content-Type=image/png]...
# Copying file://test/9/7647.png [Content-Type=image/png]...
# Copying file://test/9/1425.png [Content-Type=image/png]...
# Copying file://test/9/3086.png [Content-Type=image/png]...
# Copying file://test/9/3997.png [Content-Type=image/png]...
# Copying file://test/9/1203.png [Content-Type=image/png]...
# Copying file://test/9/1756.png [Content-Type=image/png]...
# Copying file://test/9/2439.png [Content-Type=image/png]...
# Copying file://test/9/3510.png [Content-Type=image/png]...
# Copying file://test/9/4336.png [Content-Type=image/png]...
# Copying file://test/9/3896.png [Content-Type=image/png]...
# Copying file://test/9/7077.png [Content-Type=image/png]...
# Copying file://test/9/4487.png [Content-Type=image/png]...
# Copying file://test/9/1897.png [Content-Type=image/png]...
# Copying file://test/9/5057.png [Content-Type=image/png]...
# Copying file://test/9/1707.png [Content-Type=image/png]...
# Copying file://test/9/2468.png [Content-Type=image/png]...
# Copying file://test/9/5236.png [Content-Type=image/png]...
# Copying file://test/9/5021.png [Content-Type=image/png]...
# Copying file://test/9/3558.png [Content-Type=image/png]...
# Copying file://test/9/2344.png [Content-Type=image/png]...
# Copying file://test/9/282.png [Content-Type=image/png]...
# Copying file://test/9/4725.png [Content-Type=image/png]...
# Copying file://test/9/7078.png [Content-Type=image/png]...
# Copying file://test/9/7907.png [Content-Type=image/png]...
# Copying file://test/9/6522.png [Content-Type=image/png]...
# Copying file://test/9/1721.png [Content-Type=image/png]...
# Copying file://test/9/6965.png [Content-Type=image/png]...
# Copying file://test/9/4842.png [Content-Type=image/png]...
# Copying file://test/9/1845.png [Content-Type=image/png]...
# Copying file://test/9/1021.png [Content-Type=image/png]...
# Copying file://test/9/711.png [Content-Type=image/png]...
# Copying file://test/9/7300.png [Content-Type=image/png]...
# Copying file://test/9/3955.png [Content-Type=image/png]...
# Copying file://test/9/942.png [Content-Type=image/png]...
# Copying file://test/9/3443.png [Content-Type=image/png]...
# Copying file://test/9/104.png [Content-Type=image/png]...
# Copying file://test/9/4284.png [Content-Type=image/png]...
# Copying file://test/9/3620.png [Content-Type=image/png]...
# Copying file://test/9/4699.png [Content-Type=image/png]...
# Copying file://test/9/5649.png [Content-Type=image/png]...
# Copying file://test/9/2758.png [Content-Type=image/png]...
# Copying file://test/9/5249.png [Content-Type=image/png]...
# Copying file://test/9/2230.png [Content-Type=image/png]...
# Copying file://test/9/4325.png [Content-Type=image/png]...
# Copying file://test/9/6813.png [Content-Type=image/png]...
# Copying file://test/9/3948.png [Content-Type=image/png]...
# Copying file://test/9/2426.png [Content-Type=image/png]...
# Copying file://test/9/5078.png [Content-Type=image/png]...
# Copying file://test/9/800.png [Content-Type=image/png]...
# Copying file://test/9/7460.png [Content-Type=image/png]...
# Copying file://test/9/3091.png [Content-Type=image/png]...
# Copying file://test/9/1983.png [Content-Type=image/png]...
# Copying file://test/9/1650.png [Content-Type=image/png]...
# Copying file://test/9/7889.png [Content-Type=image/png]...
# Copying file://test/9/4152.png [Content-Type=image/png]...
# Copying file://test/9/2232.png [Content-Type=image/png]...
# Copying file://test/9/4043.png [Content-Type=image/png]...
# Copying file://test/9/1437.png [Content-Type=image/png]...
# Copying file://test/9/2779.png [Content-Type=image/png]...
# Copying file://test/9/842.png [Content-Type=image/png]...
# Copying file://test/9/237.png [Content-Type=image/png]...
# Copying file://test/9/6839.png [Content-Type=image/png]...
# Copying file://test/9/6221.png [Content-Type=image/png]...
# Copying file://test/9/4064.png [Content-Type=image/png]...
# Copying file://test/9/7817.png [Content-Type=image/png]...
# Copying file://test/9/6394.png [Content-Type=image/png]...
# Copying file://test/9/2609.png [Content-Type=image/png]...
# Copying file://test/9/1334.png [Content-Type=image/png]...
# Copying file://test/9/3315.png [Content-Type=image/png]...
# Copying file://test/9/4865.png [Content-Type=image/png]...
# Copying file://test/9/6108.png [Content-Type=image/png]...
# Copying file://test/9/6006.png [Content-Type=image/png]...
# Copying file://test/9/4029.png [Content-Type=image/png]...
# Copying file://test/9/1954.png [Content-Type=image/png]...
# Copying file://test/9/1444.png [Content-Type=image/png]...
# Copying file://test/9/870.png [Content-Type=image/png]...
# Copying file://test/9/3009.png [Content-Type=image/png]...
# Copying file://test/9/4528.png [Content-Type=image/png]...
# Copying file://test/9/2241.png [Content-Type=image/png]...
# Copying file://test/9/2406.png [Content-Type=image/png]...
# Copying file://test/9/7623.png [Content-Type=image/png]...
# Copying file://test/9/266.png [Content-Type=image/png]...
# Copying file://test/9/5639.png [Content-Type=image/png]...
# Copying file://test/9/2476.png [Content-Type=image/png]...
# Copying file://test/9/7946.png [Content-Type=image/png]...
# ...
# Copying file://unlabeled/54547.png [Content-Type=image/png]...
# Copying file://unlabeled/20260.png [Content-Type=image/png]...
# Copying file://unlabeled/67496.png [Content-Type=image/png]...
# Copying file://unlabeled/80271.png [Content-Type=image/png]...
# Copying file://unlabeled/84460.png [Content-Type=image/png]...
# Copying file://unlabeled/74007.png [Content-Type=image/png]...
# Copying file://unlabeled/91236.png [Content-Type=image/png]...
# Copying file://unlabeled/12426.png [Content-Type=image/png]...
# Copying file://unlabeled/30446.png [Content-Type=image/png]...
# Copying file://unlabeled/33678.png [Content-Type=image/png]...
# Copying file://unlabeled/12193.png [Content-Type=image/png]...
# Copying file://unlabeled/96418.png [Content-Type=image/png]...
# Copying file://unlabeled/76640.png [Content-Type=image/png]...
# Copying file://unlabeled/9494.png [Content-Type=image/png]...
# Copying file://unlabeled/5421.png [Content-Type=image/png]...
# Copying file://unlabeled/93142.png [Content-Type=image/png]...
# Copying file://unlabeled/36365.png [Content-Type=image/png]...
# Copying file://unlabeled/79991.png [Content-Type=image/png]...
# Copying file://unlabeled/99604.png [Content-Type=image/png]...
# Copying file://unlabeled/8710.png [Content-Type=image/png]...
# Copying file://unlabeled/15269.png [Content-Type=image/png]...
# Copying file://unlabeled/1857.png [Content-Type=image/png]...
# Copying file://unlabeled/56402.png [Content-Type=image/png]...
# Copying file://unlabeled/39820.png [Content-Type=image/png]...
# Copying file://unlabeled/44684.png [Content-Type=image/png]...
# Copying file://unlabeled/25604.png [Content-Type=image/png]...
# Copying file://unlabeled/6469.png [Content-Type=image/png]...
# Copying file://unlabeled/5746.png [Content-Type=image/png]...
# Copying file://unlabeled/5173.png [Content-Type=image/png]...
# Copying file://unlabeled/17949.png [Content-Type=image/png]...
# Copying file://unlabeled/53939.png [Content-Type=image/png]...
# Copying file://unlabeled/4800.png [Content-Type=image/png]...
# Copying file://unlabeled/47987.png [Content-Type=image/png]...
# Copying file://unlabeled/63857.png [Content-Type=image/png]...
# Copying file://unlabeled/67708.png [Content-Type=image/png]...
# Copying file://unlabeled/89676.png [Content-Type=image/png]...
# Copying file://unlabeled/27942.png [Content-Type=image/png]...
# Copying file://unlabeled/17246.png [Content-Type=image/png]...
# Copying file://unlabeled/92862.png [Content-Type=image/png]...
# Copying file://unlabeled/96.png [Content-Type=image/png]...
# Copying file://unlabeled/15592.png [Content-Type=image/png]...
# Copying file://unlabeled/35446.png [Content-Type=image/png]...
# Copying file://unlabeled/99673.png [Content-Type=image/png]...
# Copying file://unlabeled/11764.png [Content-Type=image/png]...
# Copying file://unlabeled/43267.png [Content-Type=image/png]...
# Copying file://unlabeled/85909.png [Content-Type=image/png]...
# Copying file://unlabeled/6197.png [Content-Type=image/png]...
# Copying file://unlabeled/39145.png [Content-Type=image/png]...
# Copying file://unlabeled/84006.png [Content-Type=image/png]...
# Copying file://unlabeled/84588.png [Content-Type=image/png]...
# Copying file://unlabeled/46598.png [Content-Type=image/png]...
# Copying file://unlabeled/80994.png [Content-Type=image/png]...
# Copying file://unlabeled/79390.png [Content-Type=image/png]...
# Copying file://unlabeled/65134.png [Content-Type=image/png]...
# Copying file://unlabeled/27671.png [Content-Type=image/png]...
# Copying file://unlabeled/487.png [Content-Type=image/png]...
# Copying file://unlabeled/16738.png [Content-Type=image/png]...
# Copying file://unlabeled/59451.png [Content-Type=image/png]...
# Copying file://unlabeled/92468.png [Content-Type=image/png]...
# Copying file://unlabeled/19076.png [Content-Type=image/png]...
# Copying file://unlabeled/84983.png [Content-Type=image/png]...
# Copying file://unlabeled/64838.png [Content-Type=image/png]...
# Copying file://unlabeled/77721.png [Content-Type=image/png]...
# Copying file://unlabeled/43952.png [Content-Type=image/png]...
# Copying file://unlabeled/75093.png [Content-Type=image/png]...
# Copying file://unlabeled/98876.png [Content-Type=image/png]...
# Copying file://unlabeled/61531.png [Content-Type=image/png]...
# Copying file://unlabeled/39524.png [Content-Type=image/png]...
# Copying file://unlabeled/15939.png [Content-Type=image/png]...
# Copying file://unlabeled/77670.png [Content-Type=image/png]...
# Copying file://unlabeled/28666.png [Content-Type=image/png]...
# Copying file://unlabeled/9122.png [Content-Type=image/png]...
# Copying file://unlabeled/19647.png [Content-Type=image/png]...
# Copying file://unlabeled/62647.png [Content-Type=image/png]...
# Copying file://unlabeled/48504.png [Content-Type=image/png]...
# Copying file://unlabeled/96090.png [Content-Type=image/png]...
# Copying file://unlabeled/73231.png [Content-Type=image/png]...
# Copying file://unlabeled/3434.png [Content-Type=image/png]...
# Copying file://unlabeled/78729.png [Content-Type=image/png]...
# Copying file://unlabeled/2814.png [Content-Type=image/png]...
# Copying file://unlabeled/13262.png [Content-Type=image/png]...
# Copying file://unlabeled/85505.png [Content-Type=image/png]...
# Copying file://unlabeled/18902.png [Content-Type=image/png]...
# Copying file://unlabeled/82629.png [Content-Type=image/png]...
# Copying file://unlabeled/26892.png [Content-Type=image/png]...
# Copying file://unlabeled/51135.png [Content-Type=image/png]...
# Copying file://unlabeled/57610.png [Content-Type=image/png]...
# Copying file://unlabeled/56022.png [Content-Type=image/png]...
# Copying file://unlabeled/78311.png [Content-Type=image/png]...
# Copying file://unlabeled/3316.png [Content-Type=image/png]...
# Copying file://unlabeled/5115.png [Content-Type=image/png]...
# Copying file://unlabeled/10126.png [Content-Type=image/png]...
# Copying file://unlabeled/89736.png [Content-Type=image/png]...
# Copying file://unlabeled/94727.png [Content-Type=image/png]...
# Copying file://unlabeled/77492.png [Content-Type=image/png]...
# Copying file://unlabeled/7267.png [Content-Type=image/png]...
# Copying file://unlabeled/36243.png [Content-Type=image/png]...
# Copying file://unlabeled/30991.png [Content-Type=image/png]...
# Copying file://unlabeled/24142.png [Content-Type=image/png]...
# Copying file://unlabeled/39977.png [Content-Type=image/png]...
# Copying file://unlabeled/85237.png [Content-Type=image/png]...
# Copying file://unlabeled/94902.png [Content-Type=image/png]...
# Copying file://unlabeled/40211.png [Content-Type=image/png]...
# Copying file://unlabeled/56897.png [Content-Type=image/png]...
# Copying file://unlabeled/29769.png [Content-Type=image/png]...
# Copying file://unlabeled/73895.png [Content-Type=image/png]...
# Copying file://unlabeled/93487.png [Content-Type=image/png]...
# Copying file://unlabeled/15827.png [Content-Type=image/png]...
# Copying file://unlabeled/84577.png [Content-Type=image/png]...
# Copying file://unlabeled/67670.png [Content-Type=image/png]...
# Copying file://unlabeled/28567.png [Content-Type=image/png]...
# Copying file://unlabeled/38321.png [Content-Type=image/png]...
# Copying file://unlabeled/57657.png [Content-Type=image/png]...
# Copying file://unlabeled/12429.png [Content-Type=image/png]...
# Copying file://unlabeled/42024.png [Content-Type=image/png]...
# Copying file://unlabeled/89858.png [Content-Type=image/png]...
# Copying file://unlabeled/29487.png [Content-Type=image/png]...
# Copying file://unlabeled/92641.png [Content-Type=image/png]...
# Copying file://unlabeled/11965.png [Content-Type=image/png]...
# Copying file://unlabeled/3115.png [Content-Type=image/png]...
# Copying file://unlabeled/14257.png [Content-Type=image/png]...
# Copying file://unlabeled/67568.png [Content-Type=image/png]...
# Copying file://unlabeled/10156.png [Content-Type=image/png]...
# Copying file://unlabeled/39520.png [Content-Type=image/png]...
# Copying file://unlabeled/65135.png [Content-Type=image/png]...
# Copying file://unlabeled/32389.png [Content-Type=image/png]...
# Copying file://unlabeled/63320.png [Content-Type=image/png]...
# Copying file://unlabeled/57163.png [Content-Type=image/png]...
# Copying file://unlabeled/54165.png [Content-Type=image/png]...
# Copying file://unlabeled/32800.png [Content-Type=image/png]...
# Copying file://unlabeled/60450.png [Content-Type=image/png]...
# Copying file://unlabeled/122.png [Content-Type=image/png]...
# Copying file://unlabeled/43464.png [Content-Type=image/png]...
# Copying file://unlabeled/6292.png [Content-Type=image/png]...
# Copying file://unlabeled/43632.png [Content-Type=image/png]...
# Copying file://unlabeled/58707.png [Content-Type=image/png]...
# Copying file://unlabeled/97806.png [Content-Type=image/png]...
# Copying file://unlabeled/80005.png [Content-Type=image/png]...
# Copying file://unlabeled/38111.png [Content-Type=image/png]...
# Copying file://unlabeled/18342.png [Content-Type=image/png]...
# Copying file://unlabeled/77524.png [Content-Type=image/png]...
# Copying file://unlabeled/14305.png [Content-Type=image/png]...
# Copying file://unlabeled/11725.png [Content-Type=image/png]...
# Copying file://unlabeled/38070.png [Content-Type=image/png]...
# Copying file://unlabeled/24678.png [Content-Type=image/png]...
# Copying file://unlabeled/29499.png [Content-Type=image/png]...
# Copying file://unlabeled/59386.png [Content-Type=image/png]...
# Copying file://unlabeled/25571.png [Content-Type=image/png]...
# Copying file://unlabeled/58458.png [Content-Type=image/png]...
# Copying file://unlabeled/14571.png [Content-Type=image/png]...
# Copying file://unlabeled/53221.png [Content-Type=image/png]...
# Copying file://unlabeled/8598.png [Content-Type=image/png]...
# Copying file://unlabeled/74818.png [Content-Type=image/png]...
# Copying file://unlabeled/43550.png [Content-Type=image/png]...
# Copying file://unlabeled/82710.png [Content-Type=image/png]...
# Copying file://unlabeled/6393.png [Content-Type=image/png]...
# Copying file://unlabeled/274.png [Content-Type=image/png]...
# Copying file://unlabeled/7357.png [Content-Type=image/png]...
# Copying file://unlabeled/65256.png [Content-Type=image/png]...
# Copying file://unlabeled/82583.png [Content-Type=image/png]...
# Copying file://unlabeled/655.png [Content-Type=image/png]...
# Copying file://unlabeled/2789.png [Content-Type=image/png]...
# Copying file://unlabeled/86607.png [Content-Type=image/png]...
# Copying file://unlabeled/34002.png [Content-Type=image/png]...
# Copying file://unlabeled/84076.png [Content-Type=image/png]...
# Copying file://unlabeled/28511.png [Content-Type=image/png]...
# Copying file://unlabeled/7349.png [Content-Type=image/png]...
# Copying file://unlabeled/65052.png [Content-Type=image/png]...
# Copying file://unlabeled/14156.png [Content-Type=image/png]...
# Copying file://unlabeled/48566.png [Content-Type=image/png]...
# Copying file://unlabeled/29585.png [Content-Type=image/png]...
# Copying file://unlabeled/3793.png [Content-Type=image/png]...
# Copying file://unlabeled/19975.png [Content-Type=image/png]...
# Copying file://unlabeled/38242.png [Content-Type=image/png]...
# Copying file://unlabeled/59369.png [Content-Type=image/png]...
# Copying file://unlabeled/95511.png [Content-Type=image/png]...
# Copying file://unlabeled/55665.png [Content-Type=image/png]...
# Copying file://unlabeled/19072.png [Content-Type=image/png]...
# Copying file://unlabeled/59213.png [Content-Type=image/png]...
# Copying file://unlabeled/19190.png [Content-Type=image/png]...
# Copying file://unlabeled/67425.png [Content-Type=image/png]...
# Copying file://unlabeled/76605.png [Content-Type=image/png]...
# Copying file://unlabeled/61463.png [Content-Type=image/png]...
# Copying file://unlabeled/65166.png [Content-Type=image/png]...
# Copying file://unlabeled/40201.png [Content-Type=image/png]...
# Copying file://unlabeled/39926.png [Content-Type=image/png]...
# Copying file://unlabeled/92717.png [Content-Type=image/png]...
# Copying file://unlabeled/39261.png [Content-Type=image/png]...
# Copying file://unlabeled/44144.png [Content-Type=image/png]...
# Copying file://unlabeled/24596.png [Content-Type=image/png]...
# Copying file://unlabeled/49055.png [Content-Type=image/png]...
# Copying file://unlabeled/26598.png [Content-Type=image/png]...
# Copying file://unlabeled/60085.png [Content-Type=image/png]...
# Copying file://unlabeled/36756.png [Content-Type=image/png]...
# Copying file://unlabeled/44060.png [Content-Type=image/png]...
# Copying file://unlabeled/91020.png [Content-Type=image/png]...
# Copying file://unlabeled/4678.png [Content-Type=image/png]...
# Copying file://unlabeled/84288.png [Content-Type=image/png]...
# Copying file://unlabeled/61346.png [Content-Type=image/png]...
# Copying file://unlabeled/8623.png [Content-Type=image/png]...
# Copying file://unlabeled/14799.png [Content-Type=image/png]...
# Copying file://unlabeled/73688.png [Content-Type=image/png]...
# Copying file://unlabeled/87343.png [Content-Type=image/png]...
# Copying file://unlabeled/41278.png [Content-Type=image/png]...
# Copying file://unlabeled/44333.png [Content-Type=image/png]...
# Copying file://unlabeled/29561.png [Content-Type=image/png]...
# Copying file://unlabeled/85129.png [Content-Type=image/png]...
# Copying file://unlabeled/44631.png [Content-Type=image/png]...
# Copying file://unlabeled/45753.png [Content-Type=image/png]...
# Copying file://unlabeled/96969.png [Content-Type=image/png]...
# Copying file://unlabeled/60364.png [Content-Type=image/png]...
# Copying file://unlabeled/70863.png [Content-Type=image/png]...
# Copying file://unlabeled/20360.png [Content-Type=image/png]...
# Copying file://unlabeled/68123.png [Content-Type=image/png]...
# Copying file://unlabeled/69457.png [Content-Type=image/png]...
# Copying file://unlabeled/80385.png [Content-Type=image/png]...
# Copying file://unlabeled/87553.png [Content-Type=image/png]...
# Copying file://unlabeled/39630.png [Content-Type=image/png]...
# Copying file://unlabeled/13678.png [Content-Type=image/png]...
# Copying file://unlabeled/20267.png [Content-Type=image/png]...
# Copying file://unlabeled/21667.png [Content-Type=image/png]...
# Copying file://unlabeled/55088.png [Content-Type=image/png]...
# Copying file://unlabeled/50940.png [Content-Type=image/png]...
# Copying file://unlabeled/84436.png [Content-Type=image/png]...
# Copying file://unlabeled/52414.png [Content-Type=image/png]...
# Copying file://unlabeled/72112.png [Content-Type=image/png]...
# Copying file://unlabeled/12564.png [Content-Type=image/png]...
# Copying file://unlabeled/74523.png [Content-Type=image/png]...
# Copying file://unlabeled/61867.png [Content-Type=image/png]...
# Copying file://unlabeled/4385.png [Content-Type=image/png]...
# Copying file://unlabeled/46542.png [Content-Type=image/png]...
# Copying file://unlabeled/56803.png [Content-Type=image/png]...
# Copying file://unlabeled/4526.png [Content-Type=image/png]...
# Copying file://unlabeled/15145.png [Content-Type=image/png]...
# Copying file://unlabeled/75087.png [Content-Type=image/png]...
# Copying file://unlabeled/25803.png [Content-Type=image/png]...
# Copying file://unlabeled/55594.png [Content-Type=image/png]...
# Copying file://unlabeled/99560.png [Content-Type=image/png]...
# Copying file://unlabeled/5904.png [Content-Type=image/png]...
# Copying file://unlabeled/65001.png [Content-Type=image/png]...
# Copying file://unlabeled/5149.png [Content-Type=image/png]...
# Copying file://unlabeled/965.png [Content-Type=image/png]...
# Copying file://unlabeled/38768.png [Content-Type=image/png]...
# Copying file://unlabeled/97773.png [Content-Type=image/png]...
# Copying file://unlabeled/38824.png [Content-Type=image/png]...
# Copying file://unlabeled/99066.png [Content-Type=image/png]...
# Copying file://unlabeled/33337.png [Content-Type=image/png]...
# Copying file://unlabeled/57300.png [Content-Type=image/png]...
# Copying file://unlabeled/41821.png [Content-Type=image/png]...
# Copying file://unlabeled/76424.png [Content-Type=image/png]...
# Copying file://unlabeled/55500.png [Content-Type=image/png]...
# Copying file://unlabeled/75362.png [Content-Type=image/png]...
# Copying file://unlabeled/98158.png [Content-Type=image/png]...
# Copying file://unlabeled/46741.png [Content-Type=image/png]...
