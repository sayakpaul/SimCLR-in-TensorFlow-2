# %% [markdown]
# <a href="https://colab.research.google.com/github/sayakpaul/SimCLR-in-TensorFlow-2/blob/master/STL10_Dataset_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/mttk/STL10/master/stl10_input.py

# %%
# !python stl10_input.py

# %%
# !sudo apt-get install tree

# %%
# !mkdir stl10
# !cp -r train stl10/
# !cp -r test stl10/
# !cp -r unlabeled stl10/

# %%
# !tree --dirsfirst --filelimit 10 stl10
# Out:
# stl10
# ├── test
# │   ├── 1 [800 entries exceeds filelimit, not opening dir]
# │   ├── 10 [800 entries exceeds filelimit, not opening dir]
# │   ├── 2 [800 entries exceeds filelimit, not opening dir]
# │   ├── 3 [800 entries exceeds filelimit, not opening dir]
# │   ├── 4 [800 entries exceeds filelimit, not opening dir]
# │   ├── 5 [800 entries exceeds filelimit, not opening dir]
# │   ├── 6 [800 entries exceeds filelimit, not opening dir]
# │   ├── 7 [800 entries exceeds filelimit, not opening dir]
# │   ├── 8 [800 entries exceeds filelimit, not opening dir]
# │   └── 9 [800 entries exceeds filelimit, not opening dir]
# ├── train
# │   ├── 1 [500 entries exceeds filelimit, not opening dir]
# │   ├── 10 [500 entries exceeds filelimit, not opening dir]
# │   ├── 2 [500 entries exceeds filelimit, not opening dir]
# │   ├── 3 [500 entries exceeds filelimit, not opening dir]
# │   ├── 4 [500 entries exceeds filelimit, not opening dir]
# │   ├── 5 [500 entries exceeds filelimit, not opening dir]
# │   ├── 6 [500 entries exceeds filelimit, not opening dir]
# │   ├── 7 [500 entries exceeds filelimit, not opening dir]
# │   ├── 8 [500 entries exceeds filelimit, not opening dir]
# │   └── 9 [500 entries exceeds filelimit, not opening dir]
# └── unlabeled [100000 entries exceeds filelimit, not opening dir]
#
# 23 directories, 0 files

# %%
# Set up GCP
PROJECT_ID = "fast-ai-exploration"
# !gcloud config set project $PROJECT_ID
from google.colab import auth as google_auth
google_auth.authenticate_user()

# %%
# Create a GCS bucket and copy the images
# !gsutil mb gs://stl10
# !gsutil -m cp -r train gs://stl10
# !gsutil -m cp -r test gs://stl10
# !gsutil -m cp -r unlabeled gs://stl10
# Out:
# Creating gs://stl10/...
# Copying file://train/7/4525.png [Content-Type=image/png]...
# Copying file://train/7/3943.png [Content-Type=image/png]...
# Copying file://train/7/1377.png [Content-Type=image/png]...
# Copying file://train/7/189.png [Content-Type=image/png]...
# Copying file://train/7/1711.png [Content-Type=image/png]...
# Copying file://train/7/3210.png [Content-Type=image/png]...
# Copying file://train/7/35.png [Content-Type=image/png]...
# Copying file://train/7/2290.png [Content-Type=image/png]...
# Copying file://train/7/3103.png [Content-Type=image/png]...
# Copying file://train/7/3407.png [Content-Type=image/png]...
# Copying file://train/7/2664.png [Content-Type=image/png]...
# Copying file://train/7/2704.png [Content-Type=image/png]...
# Copying file://train/7/2792.png [Content-Type=image/png]...
# Copying file://train/7/4916.png [Content-Type=image/png]...
# Copying file://train/7/1282.png [Content-Type=image/png]...
# Copying file://train/7/4716.png [Content-Type=image/png]...
# Copying file://train/7/1898.png [Content-Type=image/png]...
# Copying file://train/7/2340.png [Content-Type=image/png]...
# Copying file://train/7/793.png [Content-Type=image/png]...
# Copying file://train/7/212.png [Content-Type=image/png]...
# Copying file://train/7/4740.png [Content-Type=image/png]...
# Copying file://train/7/3364.png [Content-Type=image/png]...
# Copying file://train/7/1284.png [Content-Type=image/png]...
# Copying file://train/7/294.png [Content-Type=image/png]...
# Copying file://train/7/2811.png [Content-Type=image/png]...
# Copying file://train/7/1398.png [Content-Type=image/png]...
# Copying file://train/7/2754.png [Content-Type=image/png]...
# Copying file://train/7/3308.png [Content-Type=image/png]...
# Copying file://train/7/3640.png [Content-Type=image/png]...
# Copying file://train/7/914.png [Content-Type=image/png]...
# Copying file://train/7/2301.png [Content-Type=image/png]...
# Copying file://train/7/1123.png [Content-Type=image/png]...
# Copying file://train/7/4831.png [Content-Type=image/png]...
# Copying file://train/7/2563.png [Content-Type=image/png]...
# Copying file://train/7/2564.png [Content-Type=image/png]...
# Copying file://train/7/4147.png [Content-Type=image/png]...
# Copying file://train/7/4174.png [Content-Type=image/png]...
# Copying file://train/7/3562.png [Content-Type=image/png]...
# Copying file://train/7/3519.png [Content-Type=image/png]...
# Copying file://train/7/3094.png [Content-Type=image/png]...
# Copying file://train/7/2749.png [Content-Type=image/png]...
# Copying file://train/7/1181.png [Content-Type=image/png]...
# Copying file://train/7/4926.png [Content-Type=image/png]...
# Copying file://train/7/4397.png [Content-Type=image/png]...
# Copying file://train/7/1626.png [Content-Type=image/png]...
# Copying file://train/7/4178.png [Content-Type=image/png]...
# Copying file://train/7/677.png [Content-Type=image/png]...
# Copying file://train/7/1966.png [Content-Type=image/png]...
# Copying file://train/7/1901.png [Content-Type=image/png]...
# Copying file://train/7/1102.png [Content-Type=image/png]...
# Copying file://train/7/3717.png [Content-Type=image/png]...
# Copying file://train/7/1563.png [Content-Type=image/png]...
# Copying file://train/7/678.png [Content-Type=image/png]...
# Copying file://train/7/2357.png [Content-Type=image/png]...
# Copying file://train/7/603.png [Content-Type=image/png]...
# Copying file://train/7/1142.png [Content-Type=image/png]...
# Copying file://train/7/2927.png [Content-Type=image/png]...
# Copying file://train/7/3420.png [Content-Type=image/png]...
# Copying file://train/7/3197.png [Content-Type=image/png]...
# Copying file://train/7/4815.png [Content-Type=image/png]...
# Copying file://train/7/275.png [Content-Type=image/png]...
# Copying file://train/7/1670.png [Content-Type=image/png]...
# Copying file://train/7/2003.png [Content-Type=image/png]...
# Copying file://train/7/3972.png [Content-Type=image/png]...
# Copying file://train/7/653.png [Content-Type=image/png]...
# Copying file://train/7/1434.png [Content-Type=image/png]...
# Copying file://train/7/2538.png [Content-Type=image/png]...
# Copying file://train/7/570.png [Content-Type=image/png]...
# Copying file://train/7/11.png [Content-Type=image/png]...
# Copying file://train/7/2525.png [Content-Type=image/png]...
# Copying file://train/7/3750.png [Content-Type=image/png]...
# Copying file://train/7/4296.png [Content-Type=image/png]...
# Copying file://train/7/2822.png [Content-Type=image/png]...
# Copying file://train/7/1495.png [Content-Type=image/png]...
# Copying file://train/7/4969.png [Content-Type=image/png]...
# Copying file://train/7/2655.png [Content-Type=image/png]...
# Copying file://train/7/128.png [Content-Type=image/png]...
# Copying file://train/7/2652.png [Content-Type=image/png]...
# Copying file://train/7/2816.png [Content-Type=image/png]...
# Copying file://train/7/1509.png [Content-Type=image/png]...
# Copying file://train/7/918.png [Content-Type=image/png]...
# Copying file://train/7/3473.png [Content-Type=image/png]...
# Copying file://train/7/1865.png [Content-Type=image/png]...
# Copying file://train/7/3645.png [Content-Type=image/png]...
# Copying file://train/7/3238.png [Content-Type=image/png]...
# Copying file://train/7/415.png [Content-Type=image/png]...
# Copying file://train/7/3355.png [Content-Type=image/png]...
# Copying file://train/7/4537.png [Content-Type=image/png]...
# Copying file://train/7/1367.png [Content-Type=image/png]...
# Copying file://train/7/2971.png [Content-Type=image/png]...
# Copying file://train/7/876.png [Content-Type=image/png]...
# Copying file://train/7/4126.png [Content-Type=image/png]...
# Copying file://train/7/2974.png [Content-Type=image/png]...
# Copying file://train/7/1217.png [Content-Type=image/png]...
# Copying file://train/7/2187.png [Content-Type=image/png]...
# Copying file://train/7/605.png [Content-Type=image/png]...
# Copying file://train/7/2625.png [Content-Type=image/png]...
# Copying file://train/7/2560.png [Content-Type=image/png]...
# Copying file://train/7/2984.png [Content-Type=image/png]...
# Copying file://train/7/3830.png [Content-Type=image/png]...
# Copying file://train/7/950.png [Content-Type=image/png]...
# Copying file://train/7/147.png [Content-Type=image/png]...
# Copying file://train/7/1096.png [Content-Type=image/png]...
# Copying file://train/7/4033.png [Content-Type=image/png]...
# Copying file://train/7/3872.png [Content-Type=image/png]...
# Copying file://train/7/390.png [Content-Type=image/png]...
# Copying file://train/7/589.png [Content-Type=image/png]...
# Copying file://train/7/2320.png [Content-Type=image/png]...
# Copying file://train/7/4019.png [Content-Type=image/png]...
# Copying file://train/7/943.png [Content-Type=image/png]...
# Copying file://train/7/334.png [Content-Type=image/png]...
# Copying file://train/7/1663.png [Content-Type=image/png]...
# Copying file://train/7/2785.png [Content-Type=image/png]...
# Copying file://train/7/2198.png [Content-Type=image/png]...
# Copying file://train/7/1129.png [Content-Type=image/png]...
# Copying file://train/7/1229.png [Content-Type=image/png]...
# Copying file://train/7/2128.png [Content-Type=image/png]...
# Copying file://train/7/4902.png [Content-Type=image/png]...
# Copying file://train/7/2083.png [Content-Type=image/png]...
# Copying file://train/7/3917.png [Content-Type=image/png]...
# Copying file://train/7/2130.png [Content-Type=image/png]...
# Copying file://train/7/3032.png [Content-Type=image/png]...
# Copying file://train/7/862.png [Content-Type=image/png]...
# Copying file://train/7/3565.png [Content-Type=image/png]...
# Copying file://train/7/3521.png [Content-Type=image/png]...
# Copying file://train/7/4156.png [Content-Type=image/png]...
# Copying file://train/7/4535.png [Content-Type=image/png]...
# Copying file://train/7/3149.png [Content-Type=image/png]...
# Copying file://train/7/1964.png [Content-Type=image/png]...
# Copying file://train/7/1324.png [Content-Type=image/png]...
# Copying file://train/7/1376.png [Content-Type=image/png]...
# Copying file://train/7/1164.png [Content-Type=image/png]...
# Copying file://train/7/4202.png [Content-Type=image/png]...
# Copying file://train/7/738.png [Content-Type=image/png]...
# Copying file://train/7/4340.png [Content-Type=image/png]...
# Copying file://train/7/1628.png [Content-Type=image/png]...
# Copying file://train/7/54.png [Content-Type=image/png]...
# Copying file://train/7/2843.png [Content-Type=image/png]...
# Copying file://train/7/1313.png [Content-Type=image/png]...
# Copying file://train/7/3862.png [Content-Type=image/png]...
# Copying file://train/7/3662.png [Content-Type=image/png]...
# Copying file://train/7/895.png [Content-Type=image/png]...
# Copying file://train/7/1187.png [Content-Type=image/png]...
# Copying file://train/7/475.png [Content-Type=image/png]...
# Copying file://train/7/873.png [Content-Type=image/png]...
# Copying file://train/7/2881.png [Content-Type=image/png]...
# Copying file://train/7/4679.png [Content-Type=image/png]...
# Copying file://train/7/2117.png [Content-Type=image/png]...
# Copying file://train/7/3916.png [Content-Type=image/png]...
# Copying file://train/7/538.png [Content-Type=image/png]...
# Copying file://train/7/3033.png [Content-Type=image/png]...
# Copying file://train/7/1848.png [Content-Type=image/png]...
# Copying file://train/7/57.png [Content-Type=image/png]...
# Copying file://train/7/2716.png [Content-Type=image/png]...
# Copying file://train/7/2623.png [Content-Type=image/png]...
# Copying file://train/7/357.png [Content-Type=image/png]...
# Copying file://train/7/3883.png [Content-Type=image/png]...
# Copying file://train/7/1248.png [Content-Type=image/png]...
# Copying file://train/7/463.png [Content-Type=image/png]...
# Copying file://train/7/2294.png [Content-Type=image/png]...
# Copying file://train/7/4390.png [Content-Type=image/png]...
# Copying file://train/7/1935.png [Content-Type=image/png]...
# Copying file://train/7/3055.png [Content-Type=image/png]...
# Copying file://train/7/2176.png [Content-Type=image/png]...
# Copying file://train/7/2286.png [Content-Type=image/png]...
# Copying file://train/7/86.png [Content-Type=image/png]...
# Copying file://train/7/2554.png [Content-Type=image/png]...
# Copying file://train/7/2104.png [Content-Type=image/png]...
# Copying file://train/7/3909.png [Content-Type=image/png]...
# Copying file://train/7/3039.png [Content-Type=image/png]...
# Copying file://train/7/3322.png [Content-Type=image/png]...
# Copying file://train/7/2999.png [Content-Type=image/png]...
# Copying file://train/7/3856.png [Content-Type=image/png]...
# Copying file://train/7/3809.png [Content-Type=image/png]...
# Copying file://train/7/3179.png [Content-Type=image/png]...
# Copying file://train/7/1177.png [Content-Type=image/png]...
# Copying file://train/7/4846.png [Content-Type=image/png]...
# Copying file://train/7/701.png [Content-Type=image/png]...
# Copying file://train/7/2589.png [Content-Type=image/png]...
# Copying file://train/7/3529.png [Content-Type=image/png]...
# Copying file://train/7/4392.png [Content-Type=image/png]...
# Copying file://train/7/3408.png [Content-Type=image/png]...
# Copying file://train/7/3117.png [Content-Type=image/png]...
# Copying file://train/7/4110.png [Content-Type=image/png]...
# Copying file://train/7/2597.png [Content-Type=image/png]...
# Copying file://train/7/3628.png [Content-Type=image/png]...
# Copying file://train/7/461.png [Content-Type=image/png]...
# Copying file://train/7/2123.png [Content-Type=image/png]...
# Copying file://train/7/4518.png [Content-Type=image/png]...
# Copying file://train/7/94.png [Content-Type=image/png]...
# Copying file://train/7/387.png [Content-Type=image/png]...
# Copying file://train/7/3177.png [Content-Type=image/png]...
# Copying file://train/7/2877.png [Content-Type=image/png]...
# Copying file://train/7/1586.png [Content-Type=image/png]...
# Copying file://train/7/3133.png [Content-Type=image/png]...
# Copying file://train/7/1209.png [Content-Type=image/png]...
# Copying file://train/7/291.png [Content-Type=image/png]...
# Copying file://train/7/639.png [Content-Type=image/png]...
# Copying file://train/7/22.png [Content-Type=image/png]...
# Copying file://train/7/2821.png [Content-Type=image/png]...
# Copying file://train/7/497.png [Content-Type=image/png]...
# Copying file://train/7/4297.png [Content-Type=image/png]...
# Copying file://train/7/3704.png [Content-Type=image/png]...
# Copying file://train/7/3787.png [Content-Type=image/png]...
# Copying file://train/7/171.png [Content-Type=image/png]...
# Copying file://train/7/4908.png [Content-Type=image/png]...
# Copying file://train/7/3508.png [Content-Type=image/png]...
# Copying file://train/7/4353.png [Content-Type=image/png]...
# Copying file://train/7/2283.png [Content-Type=image/png]...
# Copying file://train/7/1402.png [Content-Type=image/png]...
# Copying file://train/7/2820.png [Content-Type=image/png]...
# Copying file://train/7/1737.png [Content-Type=image/png]...
# Copying file://train/7/1778.png [Content-Type=image/png]...
# Copying file://train/7/4542.png [Content-Type=image/png]...
# Copying file://train/7/4472.png [Content-Type=image/png]...
# Copying file://train/7/473.png [Content-Type=image/png]...
# Copying file://train/7/386.png [Content-Type=image/png]...
# Copying file://train/7/692.png [Content-Type=image/png]...
# Copying file://train/7/3362.png [Content-Type=image/png]...
# Copying file://train/7/4540.png [Content-Type=image/png]...
# Copying file://train/7/1648.png [Content-Type=image/png]...
# Copying file://train/7/4218.png [Content-Type=image/png]...
# Copying file://train/7/2730.png [Content-Type=image/png]...
# Copying file://train/7/2662.png [Content-Type=image/png]...
# Copying file://train/7/3458.png [Content-Type=image/png]...
# Copying file://train/7/3268.png [Content-Type=image/png]...
# Copying file://train/7/4129.png [Content-Type=image/png]...
# Copying file://train/7/3320.png [Content-Type=image/png]...
# Copying file://train/7/2432.png [Content-Type=image/png]...
# Copying file://train/7/1540.png [Content-Type=image/png]...
# Copying file://train/7/4105.png [Content-Type=image/png]...
# Copying file://train/7/4324.png [Content-Type=image/png]...
# Copying file://train/7/308.png [Content-Type=image/png]...
# Copying file://train/7/2162.png [Content-Type=image/png]...
# Copying file://train/7/15.png [Content-Type=image/png]...
# Copying file://train/7/3702.png [Content-Type=image/png]...
# Copying file://train/7/2874.png [Content-Type=image/png]...
# Copying file://train/7/4639.png [Content-Type=image/png]...
# Copying file://train/7/3079.png [Content-Type=image/png]...
# Copying file://train/7/2251.png [Content-Type=image/png]...
# Copying file://train/7/3958.png [Content-Type=image/png]...
# Copying file://train/7/4991.png [Content-Type=image/png]...
# Copying file://train/7/2611.png [Content-Type=image/png]...
# Copying file://train/7/3644.png [Content-Type=image/png]...
# Copying file://train/7/3369.png [Content-Type=image/png]...
# Copying file://train/7/2409.png [Content-Type=image/png]...
# Copying file://train/7/1810.png [Content-Type=image/png]...
# Copying file://train/7/4726.png [Content-Type=image/png]...
# Copying file://train/7/3617.png [Content-Type=image/png]...
# Copying file://train/7/4442.png [Content-Type=image/png]...
# Copying file://train/7/360.png [Content-Type=image/png]...
# Copying file://train/7/2371.png [Content-Type=image/png]...
# Copying file://train/7/4976.png [Content-Type=image/png]...
# Copying file://train/7/1730.png [Content-Type=image/png]...
# Copying file://train/7/4038.png [Content-Type=image/png]...
# Copying file://train/7/3503.png [Content-Type=image/png]...
# Copying file://train/7/1309.png [Content-Type=image/png]...
# Copying file://train/7/3669.png [Content-Type=image/png]...
# Copying file://train/7/1647.png [Content-Type=image/png]...
# Copying file://train/7/4282.png [Content-Type=image/png]...
# Copying file://train/7/3854.png [Content-Type=image/png]...
# Copying file://train/7/3448.png [Content-Type=image/png]...
# Copying file://train/7/2425.png [Content-Type=image/png]...
# Copying file://train/7/93.png [Content-Type=image/png]...
# Copying file://train/7/549.png [Content-Type=image/png]...
# Copying file://train/7/1023.png [Content-Type=image/png]...
# Copying file://train/7/41.png [Content-Type=image/png]...
# Copying file://train/7/4818.png [Content-Type=image/png]...
# Copying file://train/7/1803.png [Content-Type=image/png]...
# Copying file://train/7/1735.png [Content-Type=image/png]...
# Copying file://train/7/3076.png [Content-Type=image/png]...
# Copying file://train/7/4620.png [Content-Type=image/png]...
# Copying file://train/7/3581.png [Content-Type=image/png]...
# Copying file://train/7/4492.png [Content-Type=image/png]...
# Copying file://train/7/238.png [Content-Type=image/png]...
# Copying file://train/7/4899.png [Content-Type=image/png]...
# Copying file://train/7/3.png [Content-Type=image/png]...
# Copying file://train/7/602.png [Content-Type=image/png]...
# Copying file://train/7/1347.png [Content-Type=image/png]...
# Copying file://train/7/1556.png [Content-Type=image/png]...
# Copying file://train/7/2637.png [Content-Type=image/png]...
# Copying file://train/7/2825.png [Content-Type=image/png]...
# Copying file://train/7/2621.png [Content-Type=image/png]...
# Copying file://train/7/3899.png [Content-Type=image/png]...
# Copying file://train/7/3700.png [Content-Type=image/png]...
# Copying file://train/7/385.png [Content-Type=image/png]...
# Copying file://train/7/1498.png [Content-Type=image/png]...
# Copying file://train/7/4708.png [Content-Type=image/png]...
# Copying file://train/7/229.png [Content-Type=image/png]...
# Copying file://train/7/1204.png [Content-Type=image/png]...
# Copying file://train/7/358.png [Content-Type=image/png]...
# Copying file://train/7/3555.png [Content-Type=image/png]...
# Copying file://train/7/2088.png [Content-Type=image/png]...
# Copying file://train/7/138.png [Content-Type=image/png]...
# Copying file://train/7/1292.png [Content-Type=image/png]...
# Copying file://train/7/4154.png [Content-Type=image/png]...
# Copying file://train/7/1692.png [Content-Type=image/png]...
# Copying file://train/7/4265.png [Content-Type=image/png]...
# Copying file://train/7/1425.png [Content-Type=image/png]...
# Copying file://train/7/3086.png [Content-Type=image/png]...
# Copying file://train/7/927.png [Content-Type=image/png]...
# Copying file://train/7/4026.png [Content-Type=image/png]...
# Copying file://train/7/3166.png [Content-Type=image/png]...
# Copying file://train/7/4487.png [Content-Type=image/png]...
# Copying file://train/7/551.png [Content-Type=image/png]...
# Copying file://train/7/4407.png [Content-Type=image/png]...
# Copying file://train/7/2057.png [Content-Type=image/png]...
# Copying file://train/7/4924.png [Content-Type=image/png]...
# Copying file://train/7/1051.png [Content-Type=image/png]...
# Copying file://train/7/2947.png [Content-Type=image/png]...
# Copying file://train/7/3764.png [Content-Type=image/png]...
# Copying file://train/7/973.png [Content-Type=image/png]...
# Copying file://train/7/2034.png [Content-Type=image/png]...
# Copying file://train/7/942.png [Content-Type=image/png]...
# Copying file://train/7/2382.png [Content-Type=image/png]...
# Copying file://train/7/3160.png [Content-Type=image/png]...
# Copying file://train/7/752.png [Content-Type=image/png]...
# Copying file://train/7/1872.png [Content-Type=image/png]...
# Copying file://train/7/1114.png [Content-Type=image/png]...
# Copying file://train/7/3000.png [Content-Type=image/png]...
# Copying file://train/7/4602.png [Content-Type=image/png]...
# Copying file://train/7/1058.png [Content-Type=image/png]...
# Copying file://train/7/1993.png [Content-Type=image/png]...
# Copying file://train/7/3781.png [Content-Type=image/png]...
# Copying file://train/7/845.png [Content-Type=image/png]...
# Copying file://train/7/4582.png [Content-Type=image/png]...
# Copying file://train/7/3204.png [Content-Type=image/png]...
# Copying file://train/7/4300.png [Content-Type=image/png]...
# Copying file://train/7/2850.png [Content-Type=image/png]...
# Copying file://train/7/2845.png [Content-Type=image/png]...
# Copying file://train/7/1334.png [Content-Type=image/png]...
# Copying file://train/7/3357.png [Content-Type=image/png]...
# Copying file://train/7/1806.png [Content-Type=image/png]...
# Copying file://train/7/870.png [Content-Type=image/png]...
# Copying file://train/7/2241.png [Content-Type=image/png]...
# Copying file://train/7/3520.png [Content-Type=image/png]...
# Copying file://train/7/2339.png [Content-Type=image/png]...
# Copying file://train/7/1784.png [Content-Type=image/png]...
# Copying file://train/7/2092.png [Content-Type=image/png]...
# Copying file://train/7/1439.png [Content-Type=image/png]...
# Copying file://train/7/971.png [Content-Type=image/png]...
# Copying file://train/7/4862.png [Content-Type=image/png]...
# Copying file://train/7/2841.png [Content-Type=image/png]...
# Copying file://train/7/352.png [Content-Type=image/png]...
# Copying file://train/7/4144.png [Content-Type=image/png]...
# Copying file://train/7/1979.png [Content-Type=image/png]...
# Copying file://train/7/3696.png [Content-Type=image/png]...
# Copying file://train/7/3812.png [Content-Type=image/png]...
# Copying file://train/7/4816.png [Content-Type=image/png]...
# Copying file://train/7/2733.png [Content-Type=image/png]...
# Copying file://train/7/1417.png [Content-Type=image/png]...
# Copying file://train/7/3107.png [Content-Type=image/png]...
# Copying file://train/7/2373.png [Content-Type=image/png]...
# Copying file://train/7/3164.png [Content-Type=image/png]...
# Copying file://train/7/1701.png [Content-Type=image/png]...
# Copying file://train/7/2708.png [Content-Type=image/png]...
# Copying file://train/7/2177.png [Content-Type=image/png]...
# Copying file://train/7/271.png [Content-Type=image/png]...
# Copying file://train/7/1793.png [Content-Type=image/png]...
# Copying file://train/7/3614.png [Content-Type=image/png]...
# Copying file://train/7/3096.png [Content-Type=image/png]...
# Copying file://train/7/48.png [Content-Type=image/png]...
# Copying file://train/7/4042.png [Content-Type=image/png]...
# Copying file://train/7/3488.png [Content-Type=image/png]...
# Copying file://train/7/3493.png [Content-Type=image/png]...
# Copying file://train/7/3067.png [Content-Type=image/png]...
# Copying file://train/7/860.png [Content-Type=image/png]...
# Copying file://train/7/1442.png [Content-Type=image/png]...
# Copying file://train/7/3251.png [Content-Type=image/png]...
# Copying file://train/7/625.png [Content-Type=image/png]...
# Copying file://train/7/433.png [Content-Type=image/png]...
# Copying file://train/7/3708.png [Content-Type=image/png]...
# Copying file://train/7/3910.png [Content-Type=image/png]...
# Copying file://train/7/2219.png [Content-Type=image/png]...
# Copying file://train/7/3082.png [Content-Type=image/png]...
# Copying file://train/7/1537.png [Content-Type=image/png]...
# Copying file://train/7/1902.png [Content-Type=image/png]...
# Copying file://train/7/4351.png [Content-Type=image/png]...
# Copying file://train/7/4486.png [Content-Type=image/png]...
# Copying file://train/7/2334.png [Content-Type=image/png]...
# Copying file://train/7/1710.png [Content-Type=image/png]...
# Copying file://train/7/1036.png [Content-Type=image/png]...
# Copying file://train/7/1743.png [Content-Type=image/png]...
# Copying file://train/7/4581.png [Content-Type=image/png]...
# Copying file://train/7/4888.png [Content-Type=image/png]...
# Copying file://train/7/4751.png [Content-Type=image/png]...
# Copying file://train/7/1409.png [Content-Type=image/png]...
# Copying file://train/7/3093.png [Content-Type=image/png]...
# Copying file://train/7/1933.png [Content-Type=image/png]...
# Copying file://train/7/2767.png [Content-Type=image/png]...
# Copying file://train/7/1274.png [Content-Type=image/png]...
# Copying file://train/7/17.png [Content-Type=image/png]...
# Copying file://train/7/2332.png [Content-Type=image/png]...
# Copying file://train/7/2122.png [Content-Type=image/png]...
# Copying file://train/7/3127.png [Content-Type=image/png]...
# Copying file://train/7/2460.png [Content-Type=image/png]...
# Copying file://train/7/3112.png [Content-Type=image/png]...
# Copying file://train/7/3157.png [Content-Type=image/png]...
# Copying file://train/7/217.png [Content-Type=image/png]...
# Copying file://train/7/3571.png [Content-Type=image/png]...
# Copying file://train/7/4374.png [Content-Type=image/png]...
# Copying file://train/7/1514.png [Content-Type=image/png]...
# Copying file://train/7/2488.png [Content-Type=image/png]...
# Copying file://train/7/1773.png [Content-Type=image/png]...
# Copying file://train/7/2181.png [Content-Type=image/png]...
# Copying file://train/7/3623.png [Content-Type=image/png]...
# Copying file://train/7/405.png [Content-Type=image/png]...
# Copying file://train/7/4859.png [Content-Type=image/png]...
# Copying file://train/7/1566.png [Content-Type=image/png]...
# Copying file://train/7/4547.png [Content-Type=image/png]...
# Copying file://train/7/4339.png [Content-Type=image/png]...
# Copying file://train/7/4754.png [Content-Type=image/png]...
# Copying file://train/7/829.png [Content-Type=image/png]...
# Copying file://train/7/3057.png [Content-Type=image/png]...
# Copying file://train/7/1128.png [Content-Type=image/png]...
# Copying file://train/7/2277.png [Content-Type=image/png]...
# Copying file://train/7/3419.png [Content-Type=image/png]...
# Copying file://train/7/743.png [Content-Type=image/png]...
# Copying file://train/7/4438.png [Content-Type=image/png]...
# Copying file://train/7/1651.png [Content-Type=image/png]...
# Copying file://train/7/1247.png [Content-Type=image/png]...
# Copying file://train/7/2855.png [Content-Type=image/png]...
# Copying file://train/7/3724.png [Content-Type=image/png]...
# Copying file://train/7/1198.png [Content-Type=image/png]...
# Copying file://train/7/1241.png [Content-Type=image/png]...
# Copying file://train/7/4811.png [Content-Type=image/png]...
# Copying file://train/7/2756.png [Content-Type=image/png]...
# Copying file://train/7/174.png [Content-Type=image/png]...
# Copying file://train/7/4415.png [Content-Type=image/png]...
# Copying file://train/7/2470.png [Content-Type=image/png]...
# Copying file://train/7/837.png [Content-Type=image/png]...
# Copying file://train/7/3072.png [Content-Type=image/png]...
# Copying file://train/7/50.png [Content-Type=image/png]...
# Copying file://train/7/2709.png [Content-Type=image/png]...
# Copying file://train/7/4475.png [Content-Type=image/png]...
# Copying file://train/7/264.png [Content-Type=image/png]...
# Copying file://train/7/3786.png [Content-Type=image/png]...
# Copying file://train/7/1301.png [Content-Type=image/png]...
# Copying file://train/7/2551.png [Content-Type=image/png]...
# Copying file://train/7/1144.png [Content-Type=image/png]...
# Copying file://train/7/2913.png [Content-Type=image/png]...
# Copying file://train/7/4032.png [Content-Type=image/png]...
# Copying file://train/7/3257.png [Content-Type=image/png]...
# Copying file://train/7/632.png [Content-Type=image/png]...
# Copying file://train/7/1098.png [Content-Type=image/png]...
# Copying file://train/7/844.png [Content-Type=image/png]...
# Copying file://train/7/130.png [Content-Type=image/png]...
# Copying file://train/7/4742.png [Content-Type=image/png]...
# Copying file://train/7/2559.png [Content-Type=image/png]...
# Copying file://train/7/465.png [Content-Type=image/png]...
# Copying file://train/7/438.png [Content-Type=image/png]...
# Copying file://train/7/3343.png [Content-Type=image/png]...
# Copying file://train/7/1812.png [Content-Type=image/png]...
# Copying file://train/7/4766.png [Content-Type=image/png]...
# Copying file://train/7/318.png [Content-Type=image/png]...
# Copying file://train/7/1769.png [Content-Type=image/png]...
# Copying file://train/7/1312.png [Content-Type=image/png]...
# Copying file://train/7/2485.png [Content-Type=image/png]...
# Copying file://train/7/3337.png [Content-Type=image/png]...
# Copying file://train/7/4286.png [Content-Type=image/png]...
# Copying file://train/7/2258.png [Content-Type=image/png]...
# Copying file://train/7/2577.png [Content-Type=image/png]...
# Copying file://train/7/2139.png [Content-Type=image/png]...
# Copying file://train/7/1521.png [Content-Type=image/png]...
# Copying file://train/7/935.png [Content-Type=image/png]...
# Copying file://train/7/4503.png [Content-Type=image/png]...
# Copying file://train/7/92.png [Content-Type=image/png]...
# Copying file://train/7/3557.png [Content-Type=image/png]...
# Copying file://train/7/1972.png [Content-Type=image/png]...
# Copying file://train/7/1418.png [Content-Type=image/png]...
# Copying file://train/7/4827.png [Content-Type=image/png]...
# Copying file://train/7/1518.png [Content-Type=image/png]...
# Copying file://train/7/1956.png [Content-Type=image/png]...
# Copying file://train/7/3367.png [Content-Type=image/png]...
# Copying file://train/7/528.png [Content-Type=image/png]...
# Copying file://train/7/547.png [Content-Type=image/png]...
# Copying file://train/7/2376.png [Content-Type=image/png]...
# Copying file://train/7/399.png [Content-Type=image/png]...
# Copying file://train/7/1362.png [Content-Type=image/png]...
# Copying file://train/7/2997.png [Content-Type=image/png]...
# Copying file://train/7/642.png [Content-Type=image/png]...
# Copying file://train/7/2959.png [Content-Type=image/png]...
# Copying file://train/7/4762.png [Content-Type=image/png]...
# Copying file://train/7/2570.png [Content-Type=image/png]...
# Copying file://train/7/2763.png [Content-Type=image/png]...
# Copying file://train/7/972.png [Content-Type=image/png]...
# Copying file://train/7/1433.png [Content-Type=image/png]...
# Copying file://train/7/4185.png [Content-Type=image/png]...
# Copying file://train/7/1135.png [Content-Type=image/png]...
# Copying file://train/7/1614.png [Content-Type=image/png]...
# Copying file://train/7/3388.png [Content-Type=image/png]...
# Copying file://train/7/4975.png [Content-Type=image/png]...
# Copying file://train/7/1276.png [Content-Type=image/png]...
# Copying file://train/7/761.png [Content-Type=image/png]...
# Copying file://train/7/4886.png [Content-Type=image/png]...
# Copying file://train/7/3313.png [Content-Type=image/png]...
# Copying file://train/7/3723.png [Content-Type=image/png]...
# Copying file://train/7/4011.png [Content-Type=image/png]...
# Copying file://train/7/2871.png [Content-Type=image/png]...
# Copying file://train/7/721.png [Content-Type=image/png]...
# Copying file://train/3/2907.png [Content-Type=image/png]...
# Copying file://train/3/3667.png [Content-Type=image/png]...
# Copying file://train/3/3047.png [Content-Type=image/png]...
# Copying file://train/3/2903.png [Content-Type=image/png]...
# Copying file://train/3/1908.png [Content-Type=image/png]...
# Copying file://train/3/2975.png [Content-Type=image/png]...
# Copying file://train/3/1599.png [Content-Type=image/png]...
# Copying file://train/3/1742.png [Content-Type=image/png]...
# Copying file://train/3/1009.png [Content-Type=image/png]...
# Copying file://train/3/4750.png [Content-Type=image/png]...
# Copying file://train/3/3434.png [Content-Type=image/png]...
# Copying file://train/3/2789.png [Content-Type=image/png]...
# Copying file://train/3/4729.png [Content-Type=image/png]...
# Copying file://train/3/3226.png [Content-Type=image/png]...
# Copying file://train/3/4409.png [Content-Type=image/png]...
# Copying file://train/3/3243.png [Content-Type=image/png]...
# Copying file://train/3/1916.png [Content-Type=image/png]...
# Copying file://train/3/994.png [Content-Type=image/png]...
# Copying file://train/3/2397.png [Content-Type=image/png]...
# Copying file://train/3/4072.png [Content-Type=image/png]...
# Copying file://train/3/429.png [Content-Type=image/png]...
# Copying file://train/3/2582.png [Content-Type=image/png]...
# Copying file://train/3/509.png [Content-Type=image/png]...
# Copying file://train/3/4318.png [Content-Type=image/png]...
# Copying file://train/3/4561.png [Content-Type=image/png]...
# Copying file://train/3/2607.png [Content-Type=image/png]...
# Copying file://train/3/4876.png [Content-Type=image/png]...
# Copying file://train/3/993.png [Content-Type=image/png]...
# Copying file://train/3/2499.png [Content-Type=image/png]...
# Copying file://train/3/2613.png [Content-Type=image/png]...
# Copying file://train/3/1534.png [Content-Type=image/png]...
# Copying file://train/3/799.png [Content-Type=image/png]...
# Copying file://train/3/427.png [Content-Type=image/png]...
# Copying file://train/3/4807.png [Content-Type=image/png]...
# Copying file://train/3/2271.png [Content-Type=image/png]...
# Copying file://train/3/1943.png [Content-Type=image/png]...
# Copying file://train/3/2158.png [Content-Type=image/png]...
# Copying file://train/3/1285.png [Content-Type=image/png]...
# Copying file://train/3/4971.png [Content-Type=image/png]...
# Copying file://train/3/1729.png [Content-Type=image/png]...
# Copying file://train/3/2418.png [Content-Type=image/png]...
# Copying file://train/3/4898.png [Content-Type=image/png]...
# Copying file://train/3/4103.png [Content-Type=image/png]...
# Copying file://train/3/4372.png [Content-Type=image/png]...
# Copying file://train/3/1590.png [Content-Type=image/png]...
# Copying file://train/3/60.png [Content-Type=image/png]...
# Copying file://train/3/4073.png [Content-Type=image/png]...
# Copying file://train/3/216.png [Content-Type=image/png]...
# Copying file://train/3/4660.png [Content-Type=image/png]...
# Copying file://train/3/3515.png [Content-Type=image/png]...
# Copying file://train/3/4044.png [Content-Type=image/png]...
# Copying file://train/3/3068.png [Content-Type=image/png]...
# Copying file://train/3/19.png [Content-Type=image/png]...
# Copying file://train/3/419.png [Content-Type=image/png]...
# Copying file://train/3/4348.png [Content-Type=image/png]...
# Copying file://train/3/4040.png [Content-Type=image/png]...
# Copying file://train/3/4398.png [Content-Type=image/png]...
# Copying file://train/3/1066.png [Content-Type=image/png]...
# Copying file://train/3/2052.png [Content-Type=image/png]...
# Copying file://train/3/4939.png [Content-Type=image/png]...
# Copying file://train/3/4452.png [Content-Type=image/png]...
# Copying file://train/3/1759.png [Content-Type=image/png]...
# Copying file://train/3/4427.png [Content-Type=image/png]...
# Copying file://train/3/3794.png [Content-Type=image/png]...
# Copying file://train/3/4621.png [Content-Type=image/png]...
# Copying file://train/3/2665.png [Content-Type=image/png]...
# Copying file://train/3/3162.png [Content-Type=image/png]...
# Copying file://train/3/4015.png [Content-Type=image/png]...
# Copying file://train/3/502.png [Content-Type=image/png]...
# Copying file://train/3/1722.png [Content-Type=image/png]...
# Copying file://train/3/398.png [Content-Type=image/png]...
# Copying file://train/3/3345.png [Content-Type=image/png]...
# Copying file://train/3/4504.png [Content-Type=image/png]...
# Copying file://train/3/4863.png [Content-Type=image/png]...
# Copying file://train/3/787.png [Content-Type=image/png]...
# Copying file://train/3/564.png [Content-Type=image/png]...
# Copying file://train/3/1320.png [Content-Type=image/png]...
# Copying file://train/3/1499.png [Content-Type=image/png]...
# Copying file://train/3/4153.png [Content-Type=image/png]...
# Copying file://train/3/4576.png [Content-Type=image/png]...
# Copying file://train/3/3045.png [Content-Type=image/png]...
# Copying file://train/3/4897.png [Content-Type=image/png]...
# Copying file://train/3/1827.png [Content-Type=image/png]...
# Copying file://train/3/629.png [Content-Type=image/png]...
# Copying file://train/3/59.png [Content-Type=image/png]...
# Copying file://train/3/2087.png [Content-Type=image/png]...
# Copying file://train/3/2835.png [Content-Type=image/png]...
# Copying file://train/3/2124.png [Content-Type=image/png]...
# Copying file://train/3/3031.png [Content-Type=image/png]...
# Copying file://train/3/2401.png [Content-Type=image/png]...
# Copying file://train/3/4943.png [Content-Type=image/png]...
# Copying file://train/3/3546.png [Content-Type=image/png]...
# Copying file://train/3/3495.png [Content-Type=image/png]...
# Copying file://train/3/178.png [Content-Type=image/png]...
# Copying file://train/3/468.png [Content-Type=image/png]...
# Copying file://train/3/3829.png [Content-Type=image/png]...
# Copying file://train/3/3372.png [Content-Type=image/png]...
# Copying file://train/3/2312.png [Content-Type=image/png]...
# Copying file://train/3/595.png [Content-Type=image/png]...
# Copying file://train/3/920.png [Content-Type=image/png]...
# Copying file://train/3/144.png [Content-Type=image/png]...
# Copying file://train/3/2500.png [Content-Type=image/png]...
# Copying file://train/3/906.png [Content-Type=image/png]...
# Copying file://train/3/1946.png [Content-Type=image/png]...
# Copying file://train/3/2165.png [Content-Type=image/png]...
# Copying file://train/3/4010.png [Content-Type=image/png]...
# Copying file://train/3/3311.png [Content-Type=image/png]...
# Copying file://train/3/3543.png [Content-Type=image/png]...
# Copying file://train/3/2315.png [Content-Type=image/png]...
# Copying file://train/3/4410.png [Content-Type=image/png]...
# Copying file://train/3/498.png [Content-Type=image/png]...
# Copying file://train/3/2508.png [Content-Type=image/png]...
# Copying file://train/3/3485.png [Content-Type=image/png]...
# Copying file://train/3/151.png [Content-Type=image/png]...
# Copying file://train/3/441.png [Content-Type=image/png]...
# Copying file://train/3/1843.png [Content-Type=image/png]...
# Copying file://train/3/1053.png [Content-Type=image/png]...
# Copying file://train/3/879.png [Content-Type=image/png]...
# Copying file://train/3/3760.png [Content-Type=image/png]...
# Copying file://train/3/2828.png [Content-Type=image/png]...
# Copying file://train/3/3151.png [Content-Type=image/png]...
# Copying file://train/3/1400.png [Content-Type=image/png]...
# Copying file://train/3/2802.png [Content-Type=image/png]...
# Copying file://train/3/1910.png [Content-Type=image/png]...
# Copying file://train/3/2648.png [Content-Type=image/png]...
# Copying file://train/3/3298.png [Content-Type=image/png]...
# Copying file://train/3/1855.png [Content-Type=image/png]...
# Copying file://train/3/4052.png [Content-Type=image/png]...
# Copying file://train/3/1113.png [Content-Type=image/png]...
# Copying file://train/3/1231.png [Content-Type=image/png]...
# Copying file://train/3/3966.png [Content-Type=image/png]...
# Copying file://train/3/4017.png [Content-Type=image/png]...
# Copying file://train/3/4707.png [Content-Type=image/png]...
# Copying file://train/3/673.png [Content-Type=image/png]...
# Copying file://train/3/1516.png [Content-Type=image/png]...
# Copying file://train/3/2603.png [Content-Type=image/png]...
# Copying file://train/3/4121.png [Content-Type=image/png]...
# Copying file://train/3/100.png [Content-Type=image/png]...
# Copying file://train/3/4915.png [Content-Type=image/png]...
# Copying file://train/3/4743.png [Content-Type=image/png]...
# Copying file://train/3/287.png [Content-Type=image/png]...
# Copying file://train/3/1399.png [Content-Type=image/png]...
# Copying file://train/3/1326.png [Content-Type=image/png]...
# Copying file://train/3/4176.png [Content-Type=image/png]...
# Copying file://train/3/725.png [Content-Type=image/png]...
# Copying file://train/3/3779.png [Content-Type=image/png]...
# Copying file://train/3/4739.png [Content-Type=image/png]...
# Copying file://train/3/1210.png [Content-Type=image/png]...
# Copying file://train/3/772.png [Content-Type=image/png]...
# Copying file://train/3/627.png [Content-Type=image/png]...
# Copying file://train/3/2355.png [Content-Type=image/png]...
# Copying file://train/3/2327.png [Content-Type=image/png]...
# Copying file://train/3/4755.png [Content-Type=image/png]...
# Copying file://train/3/1027.png [Content-Type=image/png]...
# Copying file://train/3/1551.png [Content-Type=image/png]...
# Copying file://train/3/3542.png [Content-Type=image/png]...
# Copying file://train/3/1315.png [Content-Type=image/png]...
# Copying file://train/3/4748.png [Content-Type=image/png]...
# Copying file://train/3/2519.png [Content-Type=image/png]...
# Copying file://train/3/3536.png [Content-Type=image/png]...
# Copying file://train/3/3466.png [Content-Type=image/png]...
# Copying file://train/3/3923.png [Content-Type=image/png]...
# Copying file://train/3/1615.png [Content-Type=image/png]...
# Copying file://train/3/2106.png [Content-Type=image/png]...
# Copying file://train/3/332.png [Content-Type=image/png]...
# Copying file://train/3/4380.png [Content-Type=image/png]...
# Copying file://train/3/2313.png [Content-Type=image/png]...
# Copying file://train/3/4242.png [Content-Type=image/png]...
# Copying file://train/3/2041.png [Content-Type=image/png]...
# Copying file://train/3/2784.png [Content-Type=image/png]...
# Copying file://train/3/960.png [Content-Type=image/png]...
# Copying file://train/3/3325.png [Content-Type=image/png]...
# Copying file://train/3/2799.png [Content-Type=image/png]...
# Copying file://train/3/3548.png [Content-Type=image/png]...
# Copying file://train/3/2584.png [Content-Type=image/png]...
# Copying file://train/3/1158.png [Content-Type=image/png]...
# Copying file://train/3/2391.png [Content-Type=image/png]...
# Copying file://train/3/1642.png [Content-Type=image/png]...
# Copying file://train/3/4860.png [Content-Type=image/png]...
# Copying file://train/3/3687.png [Content-Type=image/png]...
# Copying file://train/3/2335.png [Content-Type=image/png]...
# Copying file://train/3/2074.png [Content-Type=image/png]...
# Copying file://train/3/831.png [Content-Type=image/png]...
# Copying file://train/3/3191.png [Content-Type=image/png]...
# Copying file://train/3/1436.png [Content-Type=image/png]...
# Copying file://train/3/2077.png [Content-Type=image/png]...
# Copying file://train/3/2616.png [Content-Type=image/png]...
# Copying file://train/3/3518.png [Content-Type=image/png]...
# Copying file://train/3/3825.png [Content-Type=image/png]...
# Copying file://train/3/4758.png [Content-Type=image/png]...
# Copying file://train/3/891.png [Content-Type=image/png]...
# Copying file://train/3/2761.png [Content-Type=image/png]...
# Copying file://train/3/836.png [Content-Type=image/png]...
# Copying file://train/3/4337.png [Content-Type=image/png]...
# Copying file://train/3/3052.png [Content-Type=image/png]...
# Copying file://train/3/2192.png [Content-Type=image/png]...
# Copying file://train/3/3575.png [Content-Type=image/png]...
# Copying file://train/3/2491.png [Content-Type=image/png]...
# Copying file://train/3/491.png [Content-Type=image/png]...
# Copying file://train/3/3289.png [Content-Type=image/png]...
# Copying file://train/3/2110.png [Content-Type=image/png]...
# Copying file://train/3/4869.png [Content-Type=image/png]...
# Copying file://train/3/2260.png [Content-Type=image/png]...
# Copying file://train/3/154.png [Content-Type=image/png]...
# Copying file://train/3/3198.png [Content-Type=image/png]...
# Copying file://train/3/648.png [Content-Type=image/png]...
# Copying file://train/3/74.png [Content-Type=image/png]...
# Copying file://train/3/4861.png [Content-Type=image/png]...
# Copying file://train/3/3383.png [Content-Type=image/png]...
# Copying file://train/3/2319.png [Content-Type=image/png]...
# Copying file://train/3/3668.png [Content-Type=image/png]...
# Copying file://train/3/2157.png [Content-Type=image/png]...
# Copying file://train/3/4045.png [Content-Type=image/png]...
# Copying file://train/3/1932.png [Content-Type=image/png]...
# Copying file://train/3/3283.png [Content-Type=image/png]...
# Copying file://train/3/4609.png [Content-Type=image/png]...
# Copying file://train/3/4023.png [Content-Type=image/png]...
# Copying file://train/3/3253.png [Content-Type=image/png]...
# Copying file://train/3/303.png [Content-Type=image/png]...
# Copying file://train/3/687.png [Content-Type=image/png]...
# Copying file://train/3/443.png [Content-Type=image/png]...
# Copying file://train/3/3570.png [Content-Type=image/png]...
# Copying file://train/3/4856.png [Content-Type=image/png]...
# Copying file://train/3/667.png [Content-Type=image/png]...
# Copying file://train/3/598.png [Content-Type=image/png]...
# Copying file://train/3/4053.png [Content-Type=image/png]...
# Copying file://train/3/4965.png [Content-Type=image/png]...
# Copying file://train/3/3371.png [Content-Type=image/png]...
# Copying file://train/3/2220.png [Content-Type=image/png]...
# Copying file://train/3/591.png [Content-Type=image/png]...
# Copying file://train/3/2521.png [Content-Type=image/png]...
# Copying file://train/3/1000.png [Content-Type=image/png]...
# Copying file://train/3/4560.png [Content-Type=image/png]...
# Copying file://train/3/3288.png [Content-Type=image/png]...
# Copying file://train/3/336.png [Content-Type=image/png]...
# Copying file://train/3/2891.png [Content-Type=image/png]...
# Copying file://train/3/1079.png [Content-Type=image/png]...
# Copying file://train/3/2133.png [Content-Type=image/png]...
# Copying file://train/3/142.png [Content-Type=image/png]...
# Copying file://train/3/259.png [Content-Type=image/png]...
# Copying file://train/3/4941.png [Content-Type=image/png]...
# Copying file://train/3/2216.png [Content-Type=image/png]...
# Copying file://train/3/610.png [Content-Type=image/png]...
# Copying file://train/3/2869.png [Content-Type=image/png]...
# Copying file://train/3/3106.png [Content-Type=image/png]...
# Copying file://train/3/4445.png [Content-Type=image/png]...
# Copying file://train/3/3911.png [Content-Type=image/png]...
# Copying file://train/3/111.png [Content-Type=image/png]...
# Copying file://train/3/197.png [Content-Type=image/png]...
# Copying file://train/3/3450.png [Content-Type=image/png]...
# Copying file://train/3/4477.png [Content-Type=image/png]...
# Copying file://train/3/4954.png [Content-Type=image/png]...
# Copying file://train/3/3446.png [Content-Type=image/png]...
# Copying file://train/3/1419.png [Content-Type=image/png]...
# Copying file://train/3/1632.png [Content-Type=image/png]...
# Copying file://train/3/374.png [Content-Type=image/png]...
# Copying file://train/3/2926.png [Content-Type=image/png]...
# Copying file://train/3/1454.png [Content-Type=image/png]...
# Copying file://train/3/2912.png [Content-Type=image/png]...
# Copying file://train/3/2280.png [Content-Type=image/png]...
# Copying file://train/3/3077.png [Content-Type=image/png]...
# Copying file://train/3/1786.png [Content-Type=image/png]...
# Copying file://train/3/2952.png [Content-Type=image/png]...
# Copying file://train/3/3074.png [Content-Type=image/png]...
# Copying file://train/3/543.png [Content-Type=image/png]...
# Copying file://train/3/3174.png [Content-Type=image/png]...
# Copying file://train/3/3118.png [Content-Type=image/png]...
# Copying file://train/3/1683.png [Content-Type=image/png]...
# Copying file://train/3/4809.png [Content-Type=image/png]...
# Copying file://train/3/3368.png [Content-Type=image/png]...
# Copying file://train/3/2745.png [Content-Type=image/png]...
# Copying file://train/3/4314.png [Content-Type=image/png]...
# Copying file://train/3/1147.png [Content-Type=image/png]...
# Copying file://train/3/2129.png [Content-Type=image/png]...
# Copying file://train/3/3252.png [Content-Type=image/png]...
# Copying file://train/3/4170.png [Content-Type=image/png]...
# Copying file://train/3/4233.png [Content-Type=image/png]...
# Copying file://train/3/3377.png [Content-Type=image/png]...
# Copying file://train/3/3084.png [Content-Type=image/png]...
# Copying file://train/3/4795.png [Content-Type=image/png]...
# Copying file://train/3/161.png [Content-Type=image/png]...
# Copying file://train/3/2029.png [Content-Type=image/png]...
# Copying file://train/3/23.png [Content-Type=image/png]...
# Copying file://train/3/4937.png [Content-Type=image/png]...
# Copying file://train/3/1299.png [Content-Type=image/png]...
# Copying file://train/3/166.png [Content-Type=image/png]...
# Copying file://train/3/3893.png [Content-Type=image/png]...
# Copying file://train/3/2579.png [Content-Type=image/png]...
# Copying file://train/3/1228.png [Content-Type=image/png]...
# Copying file://train/3/2118.png [Content-Type=image/png]...
# Copying file://train/3/2546.png [Content-Type=image/png]...
# Copying file://train/3/2772.png [Content-Type=image/png]...
# Copying file://train/3/3912.png [Content-Type=image/png]...
# Copying file://train/3/4763.png [Content-Type=image/png]...
# Copying file://train/3/2764.png [Content-Type=image/png]...
# Copying file://train/3/2829.png [Content-Type=image/png]...
# Copying file://train/3/2981.png [Content-Type=image/png]...
# Copying file://train/3/581.png [Content-Type=image/png]...
# Copying file://train/3/3467.png [Content-Type=image/png]...
# Copying file://train/3/512.png [Content-Type=image/png]...
# Copying file://train/3/1593.png [Content-Type=image/png]...
# Copying file://train/3/4292.png [Content-Type=image/png]...
# ...
# Copying file://train/10/4499.png [Content-Type=image/png]...
# Copying file://train/10/784.png [Content-Type=image/png]...
# Copying file://train/10/4130.png [Content-Type=image/png]...
# Copying file://train/10/1770.png [Content-Type=image/png]...
# Copying file://train/10/4315.png [Content-Type=image/png]...
# Copying file://train/10/1254.png [Content-Type=image/png]...
# Copying file://train/10/3532.png [Content-Type=image/png]...
# Copying file://train/10/2394.png [Content-Type=image/png]...
# Copying file://train/10/479.png [Content-Type=image/png]...
# Copying file://train/10/4058.png [Content-Type=image/png]...
# Copying file://train/10/2793.png [Content-Type=image/png]...
# Copying file://train/10/3454.png [Content-Type=image/png]...
# Copying file://train/10/3281.png [Content-Type=image/png]...
# Copying file://train/10/824.png [Content-Type=image/png]...
# Copying file://train/10/2800.png [Content-Type=image/png]...
# Copying file://train/10/660.png [Content-Type=image/png]...
# Copying file://train/10/1150.png [Content-Type=image/png]...
# Copying file://train/10/62.png [Content-Type=image/png]...
# Copying file://train/10/3838.png [Content-Type=image/png]...
# Copying file://train/10/3444.png [Content-Type=image/png]...
# Copying file://train/10/4205.png [Content-Type=image/png]...
# Copying file://train/10/3214.png [Content-Type=image/png]...
# Copying file://train/10/2605.png [Content-Type=image/png]...
# Copying file://train/10/1905.png [Content-Type=image/png]...
# Copying file://train/10/2498.png [Content-Type=image/png]...
# Copying file://train/10/2430.png [Content-Type=image/png]...
# Copying file://train/10/1649.png [Content-Type=image/png]...
# Copying file://train/10/1430.png [Content-Type=image/png]...
# Copying file://train/10/218.png [Content-Type=image/png]...
# Copying file://train/10/165.png [Content-Type=image/png]...
# Copying file://train/10/3984.png [Content-Type=image/png]...
# Copying file://train/10/2933.png [Content-Type=image/png]...
# Copying file://train/10/1596.png [Content-Type=image/png]...
# Copying file://train/10/458.png [Content-Type=image/png]...
# Copying file://train/10/2299.png [Content-Type=image/png]...
# Copying file://train/10/1938.png [Content-Type=image/png]...
# Copying file://train/10/1139.png [Content-Type=image/png]...
# Copying file://train/10/1831.png [Content-Type=image/png]...
# Copying file://train/10/2011.png [Content-Type=image/png]...
# Copying file://train/10/4342.png [Content-Type=image/png]...
# Copying file://train/10/2738.png [Content-Type=image/png]...
# Copying file://train/10/1539.png [Content-Type=image/png]...
# Copying file://train/10/414.png [Content-Type=image/png]...
# Copying file://train/10/485.png [Content-Type=image/png]...
# Copying file://train/10/3969.png [Content-Type=image/png]...
# Copying file://train/10/4805.png [Content-Type=image/png]...
# Copying file://train/10/2777.png [Content-Type=image/png]...
# Copying file://train/10/4234.png [Content-Type=image/png]...
# Copying file://train/10/3010.png [Content-Type=image/png]...
# Copying file://train/10/1016.png [Content-Type=image/png]...
# Copying file://train/10/140.png [Content-Type=image/png]...
# Copying file://train/10/230.png [Content-Type=image/png]...
# Copying file://train/10/2921.png [Content-Type=image/png]...
# Copying file://train/10/1441.png [Content-Type=image/png]...
# Copying file://train/10/1492.png [Content-Type=image/png]...
# Copying file://train/10/3309.png [Content-Type=image/png]...
# Copying file://train/10/2341.png [Content-Type=image/png]...
# Copying file://train/10/1808.png [Content-Type=image/png]...
# Copying file://train/10/3817.png [Content-Type=image/png]...
# Copying file://train/10/1174.png [Content-Type=image/png]...
# Copying file://train/10/4590.png [Content-Type=image/png]...
# Copying file://train/10/3498.png [Content-Type=image/png]...
# Copying file://train/10/1610.png [Content-Type=image/png]...
# Copying file://train/10/854.png [Content-Type=image/png]...
# Copying file://train/10/4885.png [Content-Type=image/png]...
# Copying file://train/10/4127.png [Content-Type=image/png]...
# Copying file://train/10/3199.png [Content-Type=image/png]...
# Copying file://train/10/253.png [Content-Type=image/png]...
# Copying file://train/10/3525.png [Content-Type=image/png]...
# Copying file://train/10/3725.png [Content-Type=image/png]...
# Copying file://train/10/4614.png [Content-Type=image/png]...
# Copying file://train/10/778.png [Content-Type=image/png]...
# Copying file://train/10/3360.png [Content-Type=image/png]...
# Copying file://train/10/565.png [Content-Type=image/png]...
# Copying file://train/10/3974.png [Content-Type=image/png]...
# Copying file://train/10/2248.png [Content-Type=image/png]...
# Copying file://train/10/2575.png [Content-Type=image/png]...
# Copying file://train/10/396.png [Content-Type=image/png]...
# Copying file://train/10/519.png [Content-Type=image/png]...
# Copying file://train/10/4484.png [Content-Type=image/png]...
# Copying file://train/10/2602.png [Content-Type=image/png]...
# Copying file://train/10/177.png [Content-Type=image/png]...
# Copying file://train/10/573.png [Content-Type=image/png]...
# Copying file://train/10/79.png [Content-Type=image/png]...
# Copying file://train/10/4624.png [Content-Type=image/png]...
# Copying file://train/10/91.png [Content-Type=image/png]...
# Copying file://train/10/1022.png [Content-Type=image/png]...
# Copying file://train/10/1097.png [Content-Type=image/png]...
# Copying file://train/10/3379.png [Content-Type=image/png]...
# Copying file://train/10/222.png [Content-Type=image/png]...
# Copying file://train/10/456.png [Content-Type=image/png]...
# Copying file://train/10/2612.png [Content-Type=image/png]...
# Copying file://train/10/2270.png [Content-Type=image/png]...
# Copying file://train/10/864.png [Content-Type=image/png]...
# Copying file://train/10/4277.png [Content-Type=image/png]...
# Copying file://train/10/539.png [Content-Type=image/png]...
# Copying file://train/10/2097.png [Content-Type=image/png]...
# Copying file://train/10/3749.png [Content-Type=image/png]...
# Copying file://train/10/2991.png [Content-Type=image/png]...
# Copying file://train/10/1132.png [Content-Type=image/png]...
# Copying file://train/10/4373.png [Content-Type=image/png]...
# Copying file://train/10/3751.png [Content-Type=image/png]...
# Copying file://train/10/4727.png [Content-Type=image/png]...
# Copying file://train/10/1847.png [Content-Type=image/png]...
# Copying file://train/10/2436.png [Content-Type=image/png]...
# Copying file://train/10/2080.png [Content-Type=image/png]...
# Copying file://train/10/1208.png [Content-Type=image/png]...
# Copying file://train/10/175.png [Content-Type=image/png]...
# Copying file://train/10/3638.png [Content-Type=image/png]...
# Copying file://train/10/2694.png [Content-Type=image/png]...
# Copying file://train/10/1634.png [Content-Type=image/png]...
# Copying file://train/10/1195.png [Content-Type=image/png]...
# Copying file://train/10/2061.png [Content-Type=image/png]...
# Copying file://train/10/1064.png [Content-Type=image/png]...
# Copying file://train/10/1185.png [Content-Type=image/png]...
# Copying file://train/10/1640.png [Content-Type=image/png]...
# Copying file://train/10/3048.png [Content-Type=image/png]...
# Copying file://train/10/3686.png [Content-Type=image/png]...
# Copying file://train/10/1559.png [Content-Type=image/png]...
# Copying file://train/10/2134.png [Content-Type=image/png]...
# Copying file://train/10/1873.png [Content-Type=image/png]...
# Copying file://train/10/331.png [Content-Type=image/png]...
# Copying file://train/10/700.png [Content-Type=image/png]...
# Copying file://train/10/2493.png [Content-Type=image/png]...
# Copying file://train/10/688.png [Content-Type=image/png]...
# Copying file://train/10/630.png [Content-Type=image/png]...
# Copying file://train/10/3475.png [Content-Type=image/png]...
# Copying file://train/10/644.png [Content-Type=image/png]...
# Copying file://train/10/2775.png [Content-Type=image/png]...
# Copying file://train/10/2803.png [Content-Type=image/png]...
# Copying file://train/10/821.png [Content-Type=image/png]...
# Copying file://train/10/4819.png [Content-Type=image/png]...
# Copying file://train/10/4611.png [Content-Type=image/png]...
# Copying file://train/10/2832.png [Content-Type=image/png]...
# Copying file://train/10/4904.png [Content-Type=image/png]...
# Copying file://train/10/1854.png [Content-Type=image/png]...
# Copying file://train/10/2170.png [Content-Type=image/png]...
# Copying file://train/10/3291.png [Content-Type=image/png]...
# Copying file://train/10/1072.png [Content-Type=image/png]...
# Copying file://train/10/70.png [Content-Type=image/png]...
# Copying file://train/10/1776.png [Content-Type=image/png]...
# Copying file://train/10/3306.png [Content-Type=image/png]...
# Copying file://train/10/2233.png [Content-Type=image/png]...
# Copying file://train/10/1383.png [Content-Type=image/png]...
# Copying file://train/10/1676.png [Content-Type=image/png]...
# Copying file://train/10/4257.png [Content-Type=image/png]...
# Copying file://train/10/958.png [Content-Type=image/png]...
# Copying file://train/10/4102.png [Content-Type=image/png]...
# Copying file://train/10/4195.png [Content-Type=image/png]...
# Copying file://train/10/4258.png [Content-Type=image/png]...
# Copying file://train/10/1953.png [Content-Type=image/png]...
# Copying file://train/10/3476.png [Content-Type=image/png]...
# Copying file://train/10/4735.png [Content-Type=image/png]...
# Copying file://train/10/3209.png [Content-Type=image/png]...
# Copying file://train/10/1657.png [Content-Type=image/png]...
# Copying file://train/10/4845.png [Content-Type=image/png]...
# Copying file://train/10/1989.png [Content-Type=image/png]...
# Copying file://train/10/542.png [Content-Type=image/png]...
# Copying file://train/10/1751.png [Content-Type=image/png]...
# Copying file://train/10/791.png [Content-Type=image/png]...
# Copying file://train/10/4595.png [Content-Type=image/png]...
# Copying file://train/10/1303.png [Content-Type=image/png]...
# Copying file://train/10/4554.png [Content-Type=image/png]...
# Copying file://train/10/2769.png [Content-Type=image/png]...
# Copying file://train/10/2936.png [Content-Type=image/png]...
# Copying file://train/10/2244.png [Content-Type=image/png]...
# Copying file://train/10/1428.png [Content-Type=image/png]...
# Copying file://train/10/3384.png [Content-Type=image/png]...
# Copying file://train/10/969.png [Content-Type=image/png]...
# Copying file://train/10/4683.png [Content-Type=image/png]...
# Copying file://train/10/4460.png [Content-Type=image/png]...
# Copying file://train/10/1818.png [Content-Type=image/png]...
# Copying file://train/10/4607.png [Content-Type=image/png]...
# Copying file://train/10/4446.png [Content-Type=image/png]...
# Copying file://train/10/4682.png [Content-Type=image/png]...
# Copying file://train/10/2587.png [Content-Type=image/png]...
# Copying file://train/10/525.png [Content-Type=image/png]...
# Copying file://train/10/2008.png [Content-Type=image/png]...
# Copying file://train/10/2474.png [Content-Type=image/png]...
# Copying file://train/10/1049.png [Content-Type=image/png]...
# Copying file://train/10/1899.png [Content-Type=image/png]...
# Copying file://train/10/4593.png [Content-Type=image/png]...
# Copying file://train/10/4169.png [Content-Type=image/png]...
# Copying file://train/10/3948.png [Content-Type=image/png]...
# Copying file://train/10/4572.png [Content-Type=image/png]...
# Copying file://train/10/1821.png [Content-Type=image/png]...
# Copying file://train/10/2506.png [Content-Type=image/png]...
# Copying file://train/10/514.png [Content-Type=image/png]...
# Copying file://train/10/3435.png [Content-Type=image/png]...
# Copying file://train/10/3539.png [Content-Type=image/png]...
# Copying file://train/10/2783.png [Content-Type=image/png]...
# Copying file://train/10/2942.png [Content-Type=image/png]...
# Copying file://train/10/1739.png [Content-Type=image/png]...
# Copying file://train/10/4008.png [Content-Type=image/png]...
# Copying file://train/10/4064.png [Content-Type=image/png]...
# Copying file://train/10/1947.png [Content-Type=image/png]...
# Copying file://train/10/2618.png [Content-Type=image/png]...
# Copying file://train/10/1476.png [Content-Type=image/png]...
# Copying file://train/10/4122.png [Content-Type=image/png]...
# Copying file://train/10/915.png [Content-Type=image/png]...
# Copying file://train/10/423.png [Content-Type=image/png]...
# Copying file://train/10/2724.png [Content-Type=image/png]...
# Copying file://train/10/1913.png [Content-Type=image/png]...
# Copying file://train/10/1318.png [Content-Type=image/png]...
# Copying file://train/10/1877.png [Content-Type=image/png]...
# Copying file://train/10/3523.png [Content-Type=image/png]...
# Copying file://train/10/3036.png [Content-Type=image/png]...
# Copying file://train/10/1234.png [Content-Type=image/png]...
# Copying file://train/10/1448.png [Content-Type=image/png]...
# Copying file://train/10/4184.png [Content-Type=image/png]...
# Copying file://train/10/4301.png [Content-Type=image/png]...
# Copying file://train/10/2023.png [Content-Type=image/png]...
# Copying file://train/10/4402.png [Content-Type=image/png]...
# Copying file://train/10/4291.png [Content-Type=image/png]...
# Copying file://train/10/1159.png [Content-Type=image/png]...
# Copying file://train/10/3720.png [Content-Type=image/png]...
# Copying file://train/10/2630.png [Content-Type=image/png]...
# Copying file://train/10/1041.png [Content-Type=image/png]...
# Copying file://train/10/3153.png [Content-Type=image/png]...
# Copying file://train/10/944.png [Content-Type=image/png]...
# Copying file://train/10/1404.png [Content-Type=image/png]...
# Copying file://train/10/3863.png [Content-Type=image/png]...
# Copying file://train/10/919.png [Content-Type=image/png]...
# Copying file://train/10/613.png [Content-Type=image/png]...
# Copying file://train/10/2452.png [Content-Type=image/png]...
# Copying file://train/10/2099.png [Content-Type=image/png]...
# Copying file://train/10/1868.png [Content-Type=image/png]...
# Copying file://train/10/1165.png [Content-Type=image/png]...
# Copying file://train/10/3272.png [Content-Type=image/png]...
# Copying file://train/10/4449.png [Content-Type=image/png]...
# Copying file://train/10/2156.png [Content-Type=image/png]...
# Copying file://train/10/4718.png [Content-Type=image/png]...
# Copying file://train/10/4331.png [Content-Type=image/png]...
# Copying file://train/10/3752.png [Content-Type=image/png]...
# Copying file://train/10/118.png [Content-Type=image/png]...
# Copying file://train/10/4094.png [Content-Type=image/png]...
# Copying file://train/10/1180.png [Content-Type=image/png]...
# Copying file://train/10/3073.png [Content-Type=image/png]...
# Copying file://train/10/940.png [Content-Type=image/png]...
# Copying file://train/10/4080.png [Content-Type=image/png]...
# Copying file://train/10/3237.png [Content-Type=image/png]...
# Copying file://train/10/795.png [Content-Type=image/png]...
# Copying file://train/10/559.png [Content-Type=image/png]...
# Copying file://train/10/4369.png [Content-Type=image/png]...
# Copying file://train/10/575.png [Content-Type=image/png]...
# Copying file://train/10/3398.png [Content-Type=image/png]...
# Copying file://train/10/1507.png [Content-Type=image/png]...
# Copying file://train/10/85.png [Content-Type=image/png]...
# Copying file://train/10/4444.png [Content-Type=image/png]...
# Copying file://train/10/488.png [Content-Type=image/png]...
# Copying file://train/10/704.png [Content-Type=image/png]...
# Copying file://train/10/4217.png [Content-Type=image/png]...
# Copying file://train/10/3029.png [Content-Type=image/png]...
# Copying file://train/10/931.png [Content-Type=image/png]...
# Copying file://train/10/1562.png [Content-Type=image/png]...
# Copying file://train/10/4814.png [Content-Type=image/png]...
# Copying file://train/10/205.png [Content-Type=image/png]...
# Copying file://train/10/3821.png [Content-Type=image/png]...
# Copying file://train/10/4724.png [Content-Type=image/png]...
# Copying file://train/10/1531.png [Content-Type=image/png]...
# Copying file://train/10/518.png [Content-Type=image/png]...
# Copying file://train/10/4393.png [Content-Type=image/png]...
# Copying file://train/10/3017.png [Content-Type=image/png]...
